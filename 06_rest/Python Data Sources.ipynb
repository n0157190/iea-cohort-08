# %% [markdown]
# # Getting Data into Python

# %% [markdown]
# ## Agenda
# * Network / HTTP concepts
# * REST API concepts
# * Calling APIs with Python
# * Web Scraping with BeautifulSoup
# * Connecting to Databases
# * Other data sources

# %% [markdown]
# ## Getting Data from the Web

# %% [markdown]
# ## Network Fundamentals
# * Networks communicate messages between **clients** and **servers**
# * Many different protocols throughout history
# * Dominant protocol today is **TCP/IP**
# * Web requests use **HyperText Transfer Protocol (HTTP)**

# %% [markdown]
# # OSI Network Model![OSI Model](images/osi.png)

# %% [markdown]
# ### HyperText Transfer Protocol
# - This is the way our web browsers work!
# - Replaced older network protocols like gopher
# - Development of HTTP was initiated by Tim Berners-Lee at CERN in 1989
# - HTTP is a text-based protocol (not binary)
# - HTTP is *stateless* - every request must contain all contextual info!
# - HTTPS is simply HTTP over SSL (Secure Socket Layer) so that requests and responses are encrypted from client to server and back (but beware of DNS leaks!)
# - HTTP 1.1 Specification (good luck!): https://tools.ietf.org/html/rfc7231

# %% [markdown]
# # HTTP Request
# ![Network Request](images/client_server.png)

# %%
# !curl -v https://xkcd.com/
# Out:
# *   Trying 151.101.128.67:443...
# * Connected to xkcd.com (151.101.128.67) port 443 (#0)
# * ALPN, offering h2
# * ALPN, offering http/1.1
# * Cipher selection: ALL:!EXPORT:!EXPORT40:!EXPORT56:!aNULL:!LOW:!RC4:@STRENGTH
# * successfully set certificate verify locations:
# *  CAfile: /etc/pki/tls/certs/ca-bundle.crt
# *  CApath: none
# * TLSv1.2 (OUT), TLS header, Certificate Status (22):
# * TLSv1.2 (OUT), TLS handshake, Client hello (1):
# * TLSv1.2 (IN), TLS handshake, Server hello (2):
# * TLSv1.2 (IN), TLS handshake, Certificate (11):
# * TLSv1.2 (IN), TLS handshake, Server key exchange (12):
# * TLSv1.2 (IN), TLS handshake, Server finished (14):
# * TLSv1.2 (OUT), TLS handshake, Client key exchange (16):
# * TLSv1.2 (OUT), TLS change cipher, Change cipher spec (1):
# * TLSv1.2 (OUT), TLS handshake, Finished (20):
# * TLSv1.2 (IN), TLS change cipher, Change cipher spec (1):
# * TLSv1.2 (IN), TLS handshake, Finished (20):
# * SSL connection using TLSv1.2 / ECDHE-RSA-AES128-GCM-SHA256
# * ALPN, server accepted to use http/1.1
# * Server certificate:
# *  subject: CN=xkcd.com
# *  start date: Dec 24 20:45:39 2021 GMT
# *  expire date: Jan 25 20:45:38 2023 GMT
# *  subjectAltName: host "xkcd.com" matched cert's "xkcd.com"
# *  issuer: C=BE; O=GlobalSign nv-sa; CN=GlobalSign Atlas R3 DV TLS CA H2 2021
# *  SSL certificate verify ok.
# > GET / HTTP/1.1
# > Host: xkcd.com
# > User-Agent: curl/7.79.1
# > Accept: */*
# >
# * Mark bundle as not supporting multiuse
# < HTTP/1.1 200 OK
# < Connection: keep-alive
# < Content-Length: 7830
# < Server: nginx
# < Content-Type: text/html; charset=UTF-8
# < Last-Modified: Fri, 13 May 2022 13:55:50 GMT
# < ETag: "627e6366-1e96"
# < Expires: Fri, 13 May 2022 14:01:44 GMT
# < Cache-Control: max-age=300
# < Via: 1.1 varnish, 1.1 varnish
# < Accept-Ranges: bytes
# < Date: Mon, 16 May 2022 15:58:17 GMT
# < Age: 289
# < X-Served-By: cache-dfw18622-DFW, cache-iad-kjyo7100142-IAD
# < X-Cache: HIT, HIT
# < X-Cache-Hits: 1, 2
# < X-Timer: S1652716698.995655,VS0,VE0
# < Vary: Accept-Encoding
# <
# <!DOCTYPE html>
# <html>
# <head>
# <link rel="stylesheet" type="text/css" href="/s/7d94e0.css" title="Default"/>
# <title>xkcd: Crêpe</title>
# <meta http-equiv="X-UA-Compatible" content="IE=edge"/>
# <link rel="shortcut icon" href="/s/919f27.ico" type="image/x-icon"/>
# <link rel="icon" href="/s/919f27.ico" type="image/x-icon"/>
# <link rel="alternate" type="application/atom+xml" title="Atom 1.0" href="/atom.xml"/>
# <link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="/rss.xml"/>
# <script type="text/javascript" src="/s/b66ed7.js" async></script>
# <script type="text/javascript" src="/s/1b9456.js" async></script>
#
# <meta property="og:site_name" content="xkcd">
#
# <meta property="og:title" content="Crêpe">
# <meta property="og:url" content="https://xkcd.com/2619/">
# <meta property="og:image" content="https://imgs.xkcd.com/comics/crepe_2x.png">
# <meta name="twitter:card" content="summary_large_image">
#
# </head>
# <body>
# <div id="topContainer">
# <div id="topLeft">
# <ul>
# <li><a href="/archive">Archive</a></li>
# <li><a href="https://what-if.xkcd.com">What If?</a></li>
# <li><a href="https://blag.xkcd.com">Blag</a></li>
# <li><a rel="author" href="/about">About</a></li>
# <li><a href="/atom.xml">Feed</a>&bull;<a href="/newsletter/">Email</a></li>
# <li><a href="https://twitter.com/xkcd/">TW</a>&bull;<a href="https://www.facebook.com/TheXKCD/">FB</a>&bull;<a href="https://www.instagram.com/xkcd/">IG</a></li>
# <li><a href="/books/">-Books-</a></li>
# <li><a href="/what-if-2/">What If? 2</a></li>
# <li><a href="/what-if/">WI?</a>&bull;<a href="/thing-explainer/">TE</a>&bull;<a href="/how-to/">HT</a></li>
# </ul>
# </div>
# <div id="topRight">
# <div id="masthead">
# <span><a href="/"><img src="/s/0b7742.png" alt="xkcd.com logo" height="83" width="185"/></a></span>
# <span id="slogan">A webcomic of romance,<br/> sarcasm, math, and language.</span>
# </div>
# <div id="news">
# <div id="xkcdNews">
# <div id="countdown" style="float: right; margin-right: 25px; width: 160px; height: 100px; position: relative;"><a style="display: flex;" href="https://xkcd.com/what-if-2/"><img alt="" style="width: 160px; height: 100px;" src="https://xkcd.com/s/5bef6b.png"><span style="position: absolute; left: 50%; top: 50%; transform: translate(-50%, -50%); padding: 0px 8px; color: black; font-family: xkcd-Regular-v3; font-size: 20px; font-variant: small-caps; letter-spacing: 1px; white-space: nowrap; background: white none repeat scroll 0% 0%; border-radius: 99px; display: none;"></span></a></div>
# <em>What If? 2: Additional Serious Scientific Answers to Absurd Hypothetical Questions</em> comes out 9/13. Preorder <a href="https://xkcd.com/what-if-2">here!</a>
# </div>
# <script>
# var client = new XMLHttpRequest();
# client.open("GET", "//c.xkcd.com/xkcd/news", true);
# client.send();
# client.onreadystatechange = function() {
#   if(client.readyState == 4 && client.status == 200) {
#     document.getElementById("xkcdNews").innerHTML = client.responseText;
#   }
# }
# </script>
#
# </div>
# </div>
# <div id="bgLeft" class="bg box"></div>
# <div id="bgRight" class="bg box"></div>
# </div>
# <div id="middleContainer" class="box">
#
# <div id="ctitle">Crêpe</div>
# <ul class="comicNav">
# <li><a href="/1/">|&lt;</a></li>
# <li><a rel="prev" href="/2618/" accesskey="p">&lt; Prev</a></li>
# <li><a href="//c.xkcd.com/random/comic/">Random</a></li>
# <li><a rel="next" href="#" accesskey="n">Next &gt;</a></li>
# <li><a href="/">&gt;|</a></li>
# </ul>
# <div id="comic">
# <img src="//imgs.xkcd.com/comics/crepe.png" title="A medicine that makes you put two dots over your letters more often is a diäretic." alt="Crêpe" srcset="//imgs.xkcd.com/comics/crepe_2x.png 2x" style="image-orientation:none" />
# </div>
# <ul class="comicNav">
# <li><a href="/1/">|&lt;</a></li>
# <li><a rel="prev" href="/2618/" accesskey="p">&lt; Prev</a></li>
# <li><a href="//c.xkcd.com/random/comic/">Random</a></li>
# <li><a rel="next" href="#" accesskey="n">Next &gt;</a></li>
# <li><a href="/">&gt;|</a></li>
# </ul>
# <br />
# Permanent link to this comic: <a href="https://xkcd.com/2619">https://xkcd.com/2619/</a><br />
# Image URL (for hotlinking/embedding): <a href= "https://imgs.xkcd.com/comics/crepe.png">https://imgs.xkcd.com/comics/crepe.png</a>
#
# <div id="transcript" style="display: none"></div>
# </div>
# <div id="bottom" class="box">
# <img src="//imgs.xkcd.com/s/a899e84.jpg" width="520" height="100" alt="Selected Comics" usemap="#comicmap"/>
# <map id="comicmap" name="comicmap">
# <area shape="rect" coords="0,0,100,100" href="/150/" alt="Grownups"/>
# <area shape="rect" coords="104,0,204,100" href="/730/" alt="Circuit Diagram"/>
# <area shape="rect" coords="208,0,308,100" href="/162/" alt="Angular Momentum"/>
# <area shape="rect" coords="312,0,412,100" href="/688/" alt="Self-Description"/>
# <area shape="rect" coords="416,0,520,100" href="/556/" alt="Alternative Energy Revolution"/>
# </map>
# <br />
# <a href="//xkcd.com/1732/"><img border=0 src="//imgs.xkcd.com/s/temperature.png" width="520" height="100" alt="Earth temperature timeline"></a>
# <br />
# <div>
# <!--
# Search comic titles and transcripts:
# <script type="text/javascript" src="//www.google.com/jsapi"></script>
# <script type="text/javascript">google.load('search', '1');google.setOnLoadCallback(function() {google.search.CustomSearchControl.attachAutoCompletion('012652707207066138651:zudjtuwe28q',document.getElementById('q'),'cse-search-box');});</script>
# <form action="//www.google.com/cse" id="cse-search-box">
# <div>
# <input type="hidden" name="cx" value="012652707207066138651:zudjtuwe28q"/>
# <input type="hidden" name="ie" value="UTF-8"/>
# <input type="text" name="q" id="q" size="31"/>
# <input type="submit" name="sa" value="Search"/>
# </div>
# </form>
# <script type="text/javascript" src="//www.google.com/cse/brand?form=cse-search-box&amp;lang=en"></script>
# -->
# <a href="/rss.xml">RSS Feed</a> - <a href="/atom.xml">Atom Feed</a> - <a href="/newsletter/">Email</a>
# </div>
# <br />
# <div id="comicLinks">
# Comics I enjoy:<br/>
#         <a href="http://threewordphrase.com/">Three Word Phrase</a>,
#         <a href="https://www.smbc-comics.com/">SMBC</a>,
#         <a href="https://www.qwantz.com">Dinosaur Comics</a>,
#         <a href="https://oglaf.com/">Oglaf</a> (nsfw),
#         <a href="https://www.asofterworld.com">A Softer World</a>,
#         <a href="https://buttersafe.com/">Buttersafe</a>,
#         <a href="https://pbfcomics.com/">Perry Bible Fellowship</a>,
#         <a href="https://questionablecontent.net/">Questionable Content</a>,
#         <a href="http://www.buttercupfestival.com/">Buttercup Festival</a>,
#         <a href="https://www.mspaintadventures.com/">Homestuck</a>,
# 	<a href="https://www.jspowerhour.com/">Junior Scientist Power Hour</a>
# </div>
# <br />
# <div id="comicLinks">
# Other things:<br/>
#         <a href="https://medium.com/civic-tech-thoughts-from-joshdata/so-you-want-to-reform-democracy-7f3b1ef10597">Tips on technology and government</a>,<br />
#         <a href="https://www.nytimes.com/interactive/2017/climate/what-is-climate-change.html">Climate FAQ</a>,
# 	<a href="https://twitter.com/KHayhoe">Katharine Hayhoe</a>
# </div>
# <br />
# <center>
# <div id="footnote" style="width:70%">xkcd.com is best viewed with Netscape Navigator 4.0 or below on a Pentium 3&plusmn;1 emulated in Javascript on an Apple IIGS<br />at a screen resolution of 1024x1. Please enable your ad blockers, disable high-heat drying, and remove your device<br />from Airplane Mode and set it to Boat Mode. For security reasons, please leave caps lock on while browsing.</div>
# </center>
# <div id="licenseText">
# <p>
# This work is licensed under a
# <a href="https://creativecommons.org/licenses/by-nc/2.5/">Creative Commons Attribution-NonCommercial 2.5 License</a>.
# </p><p>
# This means you're free to copy and share these comics (but not to sell them). <a rel="license" href="/license.html">More details</a>.</p>
# </div>
# </div>
# </body>
# <!-- Layout by Ian Clasbey, davean, and chromakode -->
# </html>
#
# * Connection #0 to host xkcd.com left intact

# %% [markdown]
# ### HTTP Request components
# - URL
# - Verb
# - Headers (optional)
# - Body (optional)
#
# ### HTTP Response components
# - Status Code
# - Headers (optional)
# - Body (optional)

# %% [markdown]
# ### HTTP Status Code Categories
# - 1xx Informational
# - 2xx Success
# - 3xx Redirection
# - 4xx Client Error / Invalid Request (User's Fault)
# - 5xx Server Error (Server's Fault)

# %% [markdown]
# ### Common REST Status Code meanings
#
# #### 2xx
# - 200 "OK" - General Success (often overused)
# - 201 "Created" - Created a new resource on the server (usually from POST)
# - 202 "Accepted" - Request was accepted, but may not yet be completed (long process)
#
# #### 3xx
# - 301 "Moved Permanently" - URL for a resource was changed
# - 302 "Found" - The resource was found at another URL (temporary redirect, "canonical" URLs)
# - 303 "See Other" - Often the same as a 302
# - 304 "Not Modified" - Resource has not changed since the last request, use cached value
#
# #### 4xx
# - 400 "Bad Request" - Malformed requests, bad parameters, invalid formats
# - 401 "Unauthorized" - The resource requires credentials to access (i.e. requires login)
# - 403 "Forbidden" - The client does not have permission to access the resource
# - 404 "Not Found" - No resource located at this URL
# - 409 "Conflict" - Cannot edit the resource due to a conflict
# - 429 "Too Many Requests" - Used for API rate limiting
#
# #### 5xx
# - 500 "Internal Server Error" - Generic, "something went wrong" message, might indicate a bug in server code.
# - 502 "Bad Gateway" - A load balancer or proxy got no response from a webserver
# - 503 "Service Unavailable" - The server is overloaded, or down for maintenance, etc.

# %% [markdown]
# ## API (Application Programming Interface)
# * Interface specifically design for code to interact with
# * No one specification for APIs - it depends on who authors it
# * Network APIs can be binary or text, public or private, synchronous or asynchrous (and more)
# * HTTP-based APIs ("web services") have many forms - WDSL, SOAP, proprietary

# %% [markdown]
# ## REST APIs
# * __RE__presentational __S__tate __T__ransfer
# * Aims to use HTTP "as intended" to build the API
# * Familiar tools:
#     * URI (URL) uniquely identifies a "resource"
#     * HTTP verbs define what action is intended
#     * Status codes (200, 404, 500, etc) communicate results
#     * Headers provide extra info (data formats, encoding, compression)
# * Not a standard!
#     * Any data format - JSON, XML, CSV, plain text
#     * Any "resource" - Author's choice (read the docs!)

# %% [markdown]
# | HTTP Method | Description | "CRUD" Action | Request Body | Response Body | Only Reads | Idempotent | Cacheable |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | **GET** | Retrieve a resource | Read | Optional | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> |
# | **HEAD** | Retrieve headers for a resource | Read | Optional | <span style="color: red;">No</span> | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> |
# | **POST** | Post data for a resource | Create | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> | <span style="color: red;">No</span> | <span style="color: red;">No</span> | <span style="color: green;">Yes</span> |
# | **PUT** | Post data (replace) and existing resource | Update | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> | <span style="color: red;">No</span> | <span style="color: green;">Yes</span> | <span style="color: red;">No</span> |
# | **DELETE** | Delete a resource | Delete | Optional | <span style="color: green;">Yes</span> | <span style="color: red;">No</span> | <span style="color: green;">Yes</span> | <span style="color: red;">No</span> |
# | **CONNECT** | Convert connection to a tunnel | N/A | Optional | <span style="color: green;">Yes</span> | <span style="color: red;">No</span> | <span style="color: red;">No</span> | <span style="color: red;">No</span> |
# | **OPTIONS** | Request the supported methods for a resource | N/A | Optional | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> | <span style="color: red;">No</span> |
# | **TRACE** | Echo a client request for testing | N/A | <span style="color: red;">No</span> | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> | <span style="color: red;">No</span> |
# | **PATCH** | Update a resource with partial data | Update | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> | <span style="color: red;">No</span> | <span style="color: red;">No</span> | <span style="color: red;">No</span> |

# %% [markdown]
# ### Request / Response Bodies
# - The HTTP Specification does not address the format of the body
# - Requests and Responses can be sent in any format that both support
# - Common formats:  HTML, plain text, JSON, XML, YAML, etc.
# - See the **Accept** and **Content-Type** headers (and the API docs!)

# %% [markdown]
# ### Request / Response Headers
#
# - Headers are just key/value pairs (remind you of anything?)
# - Values are always just text
# - Many standard headers, but some APIs may add custom ones
#
# #### Common Headers
#
# - **Location:** Specify location of requested resource
#   Example: `Location: http://www.google.com`
# - **Content-Type:** Format of the request body
#   Example: `Content-Type: application/json`
# - **Accept:** Tells the server which body format to return
#   Example: `Accept: application/xml`
# - **User Agent:** Information about the application sending the request
#   Example: `User-Agent: curl/7.58.0`
# - **Cookies:** Misc key-value pairs stored at the client and resent on each request
#   Example: `set-cookie: NID=212=v2D4SUIJMhZuI9NWCSmaxWXm0KP01ydT-3ptgttKK3E0dn8_CoixMhU3ql1JotoZ79UbRTDThg7c9APBoipLJjSdLv0H4CLmz7ozxzzqf57Pel4bohmWDpuFcBYT7_h58lkm4-x3OPnZo09bxOJw-LJQGWkurHOnJHioz21Sd30; expires=Sat, 02-Oct-2021 12:09:52 GMT; path=/; domain=.google.com; HttpOnly`

# %% [markdown]
# ## Lab:  HTTP Requests
# Using the `curl` Linux command line tool (install it with yum if you don't have it), make some web requests to sites you know.  Use the `-v` option (verbose) to see the details of the request and response, and identify the HTTP Method, URL, and Headers.
#
# **Bonus:** Using the curl man page (or web search), find out how to send different HTTP Methods with `curl` and try a few out, even those you know may not work, to see what responses you get.

# %% [markdown]
# ## REST APIs in Python

# %% [markdown]
# ## To talk to a REST API in Python, we need to:
# * Make a web request
# * Parse the information it gives us
# * Luckily, Python gives us both in the standard library!

# %% [markdown]
# ## urllib: Package of modules for making and dealing with HTTP

# %%
from urllib.request import urlopen
SECRET_KEY = '1d8c58ed1d54f96f939e706c788650f1'

lat, long = (43.0443,-70.4528)  # Smyrna, GA

url = 'https://api.darksky.net/forecast/{key}/{lat},{long}'.format(
    key=SECRET_KEY, lat=lat, long=long)
response = urlopen(url)  # Defaults to a GET request
# Returns a file-like Response object, so we can read it just like File I/O
print(response)
print(dir(response))
# Out:
# <http.client.HTTPResponse object at 0x7f06100ed790>
# ['__abstractmethods__', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_abc_impl', '_checkClosed', '_checkReadable', '_checkSeekable', '_checkWritable', '_check_close', '_close_conn', '_get_chunk_left', '_method', '_peek_chunked', '_read1_chunked', '_read_and_discard_trailer', '_read_next_chunk_size', '_read_status', '_readall_chunked', '_readinto_chunked', '_safe_read', '_safe_readinto', 'begin', 'chunk_left', 'chunked', 'close', 'closed', 'code', 'debuglevel', 'detach', 'fileno', 'flush', 'fp', 'getcode', 'getheader', 'getheaders', 'geturl', 'headers', 'info', 'isatty', 'isclosed', 'length', 'msg', 'peek', 'read', 'read1', 'readable', 'readinto', 'readinto1', 'readline', 'readlines', 'reason', 'seek', 'seekable', 'status', 'tell', 'truncate', 'url', 'version', 'will_close', 'writable', 'write', 'writelines']

# %%
forecast_data = response.read()
print(forecast_data)
# Out:
# b'{"latitude":43.0443,"longitude":-70.4528,"timezone":"America/New_York","currently":{"time":1652801268,"summary":"Clear","icon":"clear-day","nearestStormDistance":73,"nearestStormBearing":266,"precipIntensity":0,"precipProbability":0,"temperature":59.42,"apparentTemperature":59.42,"dewPoint":49.75,"humidity":0.7,"pressure":1002.6,"windSpeed":14.63,"windGust":22.15,"windBearing":238,"cloudCover":0.06,"uvIndex":6,"visibility":10,"ozone":386.6},"minutely":{"summary":"Clear for the hour.","icon":"clear-day","data":[{"time":1652801220,"precipIntensity":0,"precipProbability":0},{"time":1652801280,"precipIntensity":0,"precipProbability":0},{"time":1652801340,"precipIntensity":0,"precipProbability":0},{"time":1652801400,"precipIntensity":0,"precipProbability":0},{"time":1652801460,"precipIntensity":0,"precipProbability":0},{"time":1652801520,"precipIntensity":0,"precipProbability":0},{"time":1652801580,"precipIntensity":0,"precipProbability":0},{"time":1652801640,"precipIntensity":0,"precipProbability":0},{"time":1652801700,"precipIntensity":0,"precipProbability":0},{"time":1652801760,"precipIntensity":0,"precipProbability":0},{"time":1652801820,"precipIntensity":0,"precipProbability":0},{"time":1652801880,"precipIntensity":0,"precipProbability":0},{"time":1652801940,"precipIntensity":0,"precipProbability":0},{"time":1652802000,"precipIntensity":0,"precipProbability":0},{"time":1652802060,"precipIntensity":0,"precipProbability":0},{"time":1652802120,"precipIntensity":0,"precipProbability":0},{"time":1652802180,"precipIntensity":0,"precipProbability":0},{"time":1652802240,"precipIntensity":0,"precipProbability":0},{"time":1652802300,"precipIntensity":0,"precipProbability":0},{"time":1652802360,"precipIntensity":0,"precipProbability":0},{"time":1652802420,"precipIntensity":0,"precipProbability":0},{"time":1652802480,"precipIntensity":0,"precipProbability":0},{"time":1652802540,"precipIntensity":0,"precipProbability":0},{"time":1652802600,"precipIntensity":0,"precipProbability":0},{"time":1652802660,"precipIntensity":0,"precipProbability":0},{"time":1652802720,"precipIntensity":0,"precipProbability":0},{"time":1652802780,"precipIntensity":0,"precipProbability":0},{"time":1652802840,"precipIntensity":0,"precipProbability":0},{"time":1652802900,"precipIntensity":0,"precipProbability":0},{"time":1652802960,"precipIntensity":0,"precipProbability":0},{"time":1652803020,"precipIntensity":0,"precipProbability":0},{"time":1652803080,"precipIntensity":0,"precipProbability":0},{"time":1652803140,"precipIntensity":0,"precipProbability":0},{"time":1652803200,"precipIntensity":0,"precipProbability":0},{"time":1652803260,"precipIntensity":0,"precipProbability":0},{"time":1652803320,"precipIntensity":0,"precipProbability":0},{"time":1652803380,"precipIntensity":0,"precipProbability":0},{"time":1652803440,"precipIntensity":0,"precipProbability":0},{"time":1652803500,"precipIntensity":0,"precipProbability":0},{"time":1652803560,"precipIntensity":0,"precipProbability":0},{"time":1652803620,"precipIntensity":0,"precipProbability":0},{"time":1652803680,"precipIntensity":0,"precipProbability":0},{"time":1652803740,"precipIntensity":0,"precipProbability":0},{"time":1652803800,"precipIntensity":0,"precipProbability":0},{"time":1652803860,"precipIntensity":0,"precipProbability":0},{"time":1652803920,"precipIntensity":0,"precipProbability":0},{"time":1652803980,"precipIntensity":0,"precipProbability":0},{"time":1652804040,"precipIntensity":0,"precipProbability":0},{"time":1652804100,"precipIntensity":0,"precipProbability":0},{"time":1652804160,"precipIntensity":0,"precipProbability":0},{"time":1652804220,"precipIntensity":0,"precipProbability":0},{"time":1652804280,"precipIntensity":0,"precipProbability":0},{"time":1652804340,"precipIntensity":0,"precipProbability":0},{"time":1652804400,"precipIntensity":0,"precipProbability":0},{"time":1652804460,"precipIntensity":0,"precipProbability":0},{"time":1652804520,"precipIntensity":0,"precipProbability":0},{"time":16 ...

# %% [markdown]
# ## json: Parsing and creating JSON-formatted data

# %%
import json

msg = json.loads('{"language": "en", "name": "Fred", "color": "blue"}')
print(msg, type(msg))
print(msg['color'])

msg['color'] = 'green'
s = json.dumps(msg)
print(s, type(s))
# Out:
# {'language': 'en', 'name': 'Fred', 'color': 'blue'} <class 'dict'>
# blue
# {"language": "en", "name": "Fred", "color": "green"} <class 'str'>

# %%
forecast = json.loads(forecast_data)
# Depending on the API, this can get really deep!  Consider breaking things down
print(type(forecast))
time = forecast['currently']['time']
temp = forecast['currently']['temperature']
print(time, temp)

today = forecast['daily']['data'][0]

print('Today - High: {high}, Low: {low}'.format(
    high=today['temperatureHigh'], low=today['temperatureLow']))
# Out:
# <class 'dict'>
# 1652801268 59.42
# Today - High: 62.93, Low: 51.11

# %%
from pprint import pprint
pprint(forecast)
# Out:
# {'currently': {'apparentTemperature': 59.42,
#                'cloudCover': 0.06,
#                'dewPoint': 49.75,
#                'humidity': 0.7,
#                'icon': 'clear-day',
#                'nearestStormBearing': 266,
#                'nearestStormDistance': 73,
#                'ozone': 386.6,
#                'precipIntensity': 0,
#                'precipProbability': 0,
#                'pressure': 1002.6,
#                'summary': 'Clear',
#                'temperature': 59.42,
#                'time': 1652801268,
#                'uvIndex': 6,
#                'visibility': 10,
#                'windBearing': 238,
#                'windGust': 22.15,
#                'windSpeed': 14.63},
#  'daily': {'data': [{'apparentTemperatureHigh': 62.43,
#                      'apparentTemperatureHighTime': 1652817060,
#                      'apparentTemperatureLow': 51.6,
#                      'apparentTemperatureLowTime': 1652868060,
#                      'apparentTemperatureMax': 62.43,
#                      'apparentTemperatureMaxTime': 1652817060,
#                      'apparentTemperatureMin': 53.63,
#                      'apparentTemperatureMinTime': 1652846400,
#                      'cloudCover': 0.27,
#                      'dewPoint': 49.36,
#                      'humidity': 0.75,
#                      'icon': 'rain',
#                      'moonPhase': 0.57,
#                      'ozone': 383,
#                      'precipIntensity': 0.0013,
#                      'precipIntensityMax': 0.0406,
#                      'precipIntensityMaxTime': 1652760000,
#                      'precipProbability': 0.59,
#                      'precipType': 'rain',
#                      'pressure': 1002.3,
#                      'summary': 'Clear throughout the day.',
#                      'sunriseTime': 1652779080,
#                      'sunsetTime': 1652832120,
#                      'temperatureHigh': 62.93,
#                      'temperatureHighTime': 1652817060,
#                      'temperatureLow': 51.11,
#                      'temperatureLowTime': 1652868060,
#                      'temperatureMax': 62.93,
#                      'temperatureMaxTime': 1652817060,
#                      'temperatureMin': 53.14,
#                      'temperatureMinTime': 1652846400,
#                      'time': 1652760000,
#                      'uvIndex': 7,
#                      'uvIndexTime': 1652805780,
#                      'visibility': 9.91,
#                      'windBearing': 251,
#                      'windGust': 28.32,
#                      'windGustTime': 1652760060,
#                      'windSpeed': 16.81},
#                     {'apparentTemperatureHigh': 60.44,
#                      'apparentTemperatureHighTime': 1652907840,
#                      'apparentTemperatureLow': 52.84,
#                      'apparentTemperatureLowTime': 1652958000,
#                      'apparentTemperatureMax': 60.44,
#                      'apparentTemperatureMaxTime': 1652907840,
#                      'apparentTemperatureMin': 51.6,
#                      'apparentTemperatureMinTime': 1652868060,
#                      'cloudCover': 0.33,
#                      'dewPoint': 43.28,
#                      'humidity': 0.63,
#                      'icon': 'clear-day',
#                      'moonPhase': 0.61,
#                      'ozone': 369.7,
#                      'precipIntensity': 0,
#                      'precipIntensityMax': 0,
#                      'precipProbability': 0,
#                      'pressure': 1010.6,
#                      'summary': 'Clear throughout the day.',
#                      'sunriseTime': 1652865420,
#                      'sunsetTime': 1652918580,
#                      'temperatureHigh': 60.94,
#                      'temperatureHighTime': 1652907840,
#                      'temperatureLow': 52.35,
#                      'temperatureLowTime': 1652958000,
#                      'temperatureMax': 60.94,
#                      'temperatureMaxTime': 1652907840,
#                      'temperatureMin': 51.11,
#                      'temperatureMinTime': 1652868060,
#                      'time': 1652846400,
#                      'uvIndex': 7,
#                      'uvIndexTime': 1652892240,
#                      'visibility': 10,
#                      'windBearing': 281,
#                      'windGust': 28.48,
#                      'windGustTime': 1652853540,
#                      'windSpeed': 12.69},
#                     {'apparentTemperatureHigh': 55.21,
#                      'apparentTemperatureHighTime': 1652973660,
#                      'apparentTemperatureLow': 51.71,
#                      'apparentTemperatureLowTime': 1653038040,
#                      'apparentTemperatureMax': 55.21,
#                      'apparentTemperatureMaxTime': 1652973660,
#                      'apparentTemperatureMin': 52.66,
#                      'apparentTemperatureMinTime': 1652985060,
#                      'cloudCover': 0.93,
#                      'dewPoint': 48.63,
#                      'humidity': 0.84,
#                      'icon': 'rain',
#                      'moonPhase': 0.65,
#                      'ozone': 357,
#                      'precipIntensity': 0.012,
#                      'precipIntensityMax': 0.062,
#                      'precipIntensityMaxTime': 1652961660,
#                      'precipProbability': 0.88,
#                      'precipType': 'rain',
#                      'pressure': 1008.8,
#                      'summary': 'Rain until evening.',
#                      'sunriseTime': 1652951760,
#                      'sunsetTime': 1653005040,
#                      'temperatureHigh': 55.71,
#                      'temperatureHighTime': 1652973660,
#                      'temperatureLow': 51.22,
#                      'temperatureLowTime': 1653038040,
#                      'temperatureMax': 55.71,
#                      'temperatureMaxTime': 1652973660,
#                      'temperatureMin': 52.17,
#                      'temperatureMinTime': 1652985060,
#                      'time': 1652932800,
#                      'uvIndex': 4,
#                      'uvIndexTime': 1652977620,
#                      'visibility': 10,
#                      'windBearing': 164,
#                      'windGust': 21.1,
#                      'windGustTime': 1652983620,
#                      'windSpeed': 10.56},
#                     {'apparentTemperatureHigh': 58.72,
#                      'apparentTemperatureHighTime': 1653082860,
#                      'apparentTemperatureLow': 56.9,
#                      'apparentTemperatureLowTime': 1653100440,
#                      'apparentTemperatureMax': 58.72,
#                      'apparentTemperatureMaxTime': 1653082860,
#                      'apparentTemperatureMin': 51.71,
#                      'apparentTemperatureMinTime': 1653038040,
#                      'cloudCover': 0.44,
#                      'dewPoint': 52.65,
#                      'humidity': 0.93,
#                      'icon': 'wind',
#                      'moonPhase': 0.69,
#                      'ozone': 343.1,
#                      'precipIntensity': 0.0002,
#                      'precipIntensityMax': 0.0008,
#                      'precipIntensityMaxTime': 1653085920,
#                      'precipProbability': 0.06,
#                      'precipType': 'rain',
#                      'pressure': 1013.2,
#                      'summary': 'Windy in the afternoon and evening.',
#                      'sunriseTime': 1653038100,
#                      'sunsetTime': 1653091500,
#                      'temperatureHigh': 59.22,
#                      'temperatureHighTime': 1653082860,
#                      'temperatureLow': 56.32,
#                      'temperatureLowTime': 1653102660,
#                      'temperatureMax': 59.22,
#                      'temperatureMaxTime': 1653082860,
#                      'temperatureMin': 51.22,
#                      'temperatureMinTime': 1653038040,
#                      'time': 1653019200,
#                      'uvIndex': 7,
#                      'uvIndexTime': 1653063720,
#                      'visibility': 9.992,
#                      'windBearing': 171,
#                      'windGust': 46.78,
#                      'windGustTime': 1653079140,
#                      'windSpeed': 12.93},
#                     {'apparentTemperatureHigh': 66.17,
#                      'apparentTemperatureHighTime': 1653163260,
#                      'apparentTemperatureLow': 60.95,
#                      'apparentTemperatureLowTime': 1653217200,
#                      'apparentTemperatureMax': 66.17,
#                      'apparentTemperatureMaxTime': 1653163260,
#                      'apparentTemperatureMin': 57.06,
#                      'apparentTemperatureMinTime': 1653105600,
#                      'cloudCover': 0.7,
#                      'dewPoint': 60.19,
#                      'humidity': 0.94,
#                      'icon': 'partly-cloudy-day',
#                      'moonPhase': 0.72,
#                      'ozone': 336.4,
#                      'precipIntensity': 0.0005,
#                      'precipIntensityMax': 0.0038,
#                      'precipIntensityMaxTime': 1653130800,
#                      'precipProbability': 0.1,
#                      'precipType': 'rain',
#                      'pressure': 1013.1,
#                      'summary': 'Mostly cloudy throughout the day.',
#                      'sunriseTime': 1653124440,
#                      'sunsetTime': 1653177960,
#                      'temperatureHigh': 66.22,
#                      'temperatureHighTime': 1653163320,
#                      'temperatureLow': 60.06,
#                      'temperatureLowTime': 1653217200,
#                      'temperatureMax': 66.22,
#                      'temperatureMaxTime': 1653163320,
#                      'temperatureMin': 56.33,
#                      'temperatureMinTime': 1653108480,
#                      'time': 1653105600,
#                      'uvIndex': 5,
#                      'uvIndexTime': 1653158220,
#                      'visibility': 10,
#                      'windBearing': 194,
#                      'windGust': 24.28,
#                      'windGustTime': 1653105600,
#                      'windSpeed': 15.44},
#                     {'apparentTemperatureHigh': 63.24,
#                      'apparentTemperatureHighTime': 1653238980,
#                      'apparentTemperatureLow': 56.64,
#                      'apparentTemperatureLowTime': 1653277860,
#                      'apparentTemperatureMax': 64.37,
#                      'apparentTemperatureMaxTime': 1653192000,
#                      'apparentTemperatureMin': 56.64,
#                      'apparentTemperatureMinTime': 1653277860,
#                      'cloudCover': 0.43,
#                      'dewPoint': 59.31,
#                      'humidity': 0.93,
#                      'icon': 'wind',
#                      'moonPhase': 0.76,
#                      'ozone': 330.6,
#                      'precipIntensity': 0.003,
#                      'precipIntensityMax': 0.0122,
#                      'precipIntensityMaxTime': 1653242580,
#                      'precipProbability': 0.37,
#                      'precipType': 'rain',
#                      'pressure': 1012.2,
#                      'summary': 'Windy in the afternoon and evening.',
#                      'sunriseTime': 1653210780,
#                      'sunsetTime': 1653264420,
#                      'temperatureHigh': 63.43,
#                      'temperatureHighTime': 1653239100,
#                      'temperatureLow': 56.15,
#                      'temperatureLowTime': 1653277860,
#                      'temperatureMax': 64.87,
#                      'temperatureMaxTime': 1653192000,
#                      'temperatureMin': 56.15,
#                      'temperatureMinTime': 1653277860,
#                      'time': 1653192000,
#                      'uvIndex': 7,
#                      'uvIndexTime': 1653236220,
#                      'visibility': 9.71,
#                      'windBearing': 191,
#                      'windGust': 46.32,
#                      'windGustTime': 1653253560,
#                      'windSpeed': 15.73},
#                     {'apparentTemperatureHigh': 59.24,
#                      'apparentTemperatureHighTime': 1653317220,
#                      'apparentTemperatureLow': 54.88,
#                      'apparentTemperatureLowTime': 1653362040,
#                      'apparentTemperatureMax': 59.24,
#                      'apparentTemperatureMaxTime': 1653317220,
#                      'apparentTemperatureMin': 54.88,
#                      'apparentTemperatureMinTime': 1653362040,
#                      'cloudCover': 0.64,
#                      'dewPoint': 53.7,
#                      'humidity': 0.88,
#                      'icon': 'partly-cloudy-day',
#                      'moonPhase': 0.79,
#                      'ozone': 338.6,
#                      'precipIntensity': 0.0001,
#                      'precipIntensityMax': 0.0023,
#                      'precipIntensityMaxTime': 1653278400,
#                      'precipProbability': 0.16,
#                      'precipType': 'rain',
#                      'pressure': 1022.4,
#                      'summary': 'Partly cloudy throughout the day.',
#                      'sunriseTime': 1653297120,
#                      'sunsetTime': 1653350880,
#                      'temperatureHigh': 59.74,
#                      'temperatureHighTime': 1653317220,
#                      'temperatureLow': 54.39,
#                      'temperatureLowTime': 1653362040,
#                      'temperatureMax': 59.74,
#                      'temperatureMaxTime': 1653317220,
#                      'temperatureMin': 54.39,
#                      'temperatureMinTime': 1653362040,
#                      'time': 1653278400,
#                      'uvIndex': 7,
#                      'uvIndexTime': 1653324060,
#                      'visibility': 10,
#                      'windBearing': 306,
#                      'windGust': 32.3,
#                      'windGustTime': 1653287340,
#                      'windSpeed': 8.33},
#                     {'apparentTemperatureHigh': 56.31,
#                      'apparentTemperatureHighTime': 1653402120,
#                      'apparentTemperatureLow': 53.95,
#                      'apparentTemperatureLowTime': 1653465360,
#                      'apparentTemperatureMax': 56.31,
#                      'apparentTemperatureMaxTime': 1653402120,
#                      'apparentTemperatureMin': 54.68,
#                      'apparentTemperatureMinTime': 1653451200,
#                      'cloudCover': 0.73,
#                      'dewPoint': 50.16,
#                      'humidity': 0.82,
#                      'icon': 'partly-cloudy-day',
#                      'moonPhase': 0.83,
#                      'ozone': 344.6,
#                      'precipIntensity': 0,
#                      'precipIntensityMax': 0,
#                      'precipProbability': 0,
#                      'pressure': 1028.3,
#                      'summary': 'Mostly cloudy throughout the day.',
#                      'sunriseTime': 1653383520,
#                      'sunsetTime': 1653437340,
#                      'temperatureHigh': 56.81,
#                      'temperatureHighTime': 1653402120,
#                      'temperatureLow': 53.46,
#                      'temperatureLowTime': 1653465360,
#                      'temperatureMax': 56.81,
#                      'temperatureMaxTime': 1653402120,
#                      'temperatureMin': 54.19,
#                      'temperatureMinTime': 1653451200,
#                      'time': 1653364800,
#                      'uvIndex': 5,
#                      'uvIndexTime': 1653413220,
#                      'visibility': 10,
#                      'windBearing': 65,
#                      'windGust': 24.98,
#                      'windGustTime': 1653443820,
#                      'windSpeed': 8.23}],
#            'icon': 'rain',
#            'summary': 'Rain today and Thursday.'},
#  'flags': {'nearest-station': 9.438,
#            'sources': ['nwspa',
#                        'cmc',
#                        'gfs',
#                        'hrrr',
#                        'icon',
#                        'isd',
#                        'madis',
#                        'nam',
#                        'sref',
#                        'darksky',
#                        'nearest-precip'],
#            'units': 'us'},
#  'hourly': {'data': [{'apparentTemperature': 58.92,
#                       'cloudCover': 0.06,
#                       'dewPoint': 49.96,
#                       'humidity': 0.72,
#                       'icon': 'clear-day',
#                       'ozone': 387.7,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1002.6,
#                       'summary': 'Clear',
#                       'temperature': 58.92,
#                       'time': 1652799600,
#                       'uvIndex': 6,
#                       'visibility': 10,
#                       'windBearing': 239,
#                       'windGust': 21.83,
#                       'windSpeed': 14.58},
#                      {'apparentTemperature': 59.91,
#                       'cloudCover': 0.06,
#                       'dewPoint': 49.46,
#                       'humidity': 0.68,
#                       'icon': 'clear-day',
#                       'ozone': 385.2,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1002.7,
#                       'summary': 'Clear',
#                       'temperature': 59.91,
#                       'time': 1652803200,
#                       'uvIndex': 7,
#                       'visibility': 10,
#                       'windBearing': 238,
#                       'windGust': 22.72,
#                       'windSpeed': 14.91},
#                      {'apparentTemperature': 60.35,
#                       'cloudCover': 0.04,
#                       'dewPoint': 49.13,
#                       'humidity': 0.66,
#                       'icon': 'clear-day',
#                       'ozone': 385.4,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1002.3,
#                       'summary': 'Clear',
#                       'temperature': 60.35,
#                       'time': 1652806800,
#                       'uvIndex': 7,
#                       'visibility': 10,
#                       'windBearing': 244,
#                       'windGust': 23.85,
#                       'windSpeed': 15.37},
#                      {'apparentTemperature': 61.56,
#                       'cloudCover': 0.05,
#                       'dewPoint': 48.37,
#                       'humidity': 0.62,
#                       'icon': 'clear-day',
#                       'ozone': 384.2,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1002.1,
#                       'summary': 'Clear',
#                       'temperature': 61.56,
#                       'time': 1652810400,
#                       'uvIndex': 6,
#                       'visibility': 10,
#                       'windBearing': 245,
#                       'windGust': 25.5,
#                       'windSpeed': 16.7},
#                      {'apparentTemperature': 62.23,
#                       'cloudCover': 0.41,
#                       'dewPoint': 47.77,
#                       'humidity': 0.59,
#                       'icon': 'partly-cloudy-day',
#                       'ozone': 383.8,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1002,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 62.23,
#                       'time': 1652814000,
#                       'uvIndex': 4,
#                       'visibility': 10,
#                       'windBearing': 252,
#                       'windGust': 27.92,
#                       'windSpeed': 18.87},
#                      {'apparentTemperature': 62.42,
#                       'cloudCover': 0.42,
#                       'dewPoint': 47.42,
#                       'humidity': 0.58,
#                       'icon': 'partly-cloudy-day',
#                       'ozone': 382.3,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1002.1,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 62.42,
#                       'time': 1652817600,
#                       'uvIndex': 3,
#                       'visibility': 10,
#                       'windBearing': 262,
#                       'windGust': 25.38,
#                       'windSpeed': 17.62},
#                      {'apparentTemperature': 62.04,
#                       'cloudCover': 0.08,
#                       'dewPoint': 47.09,
#                       'humidity': 0.58,
#                       'icon': 'clear-day',
#                       'ozone': 382.1,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1002.3,
#                       'summary': 'Clear',
#                       'temperature': 62.04,
#                       'time': 1652821200,
#                       'uvIndex': 2,
#                       'visibility': 10,
#                       'windBearing': 256,
#                       'windGust': 25.4,
#                       'windSpeed': 17.16},
#                      {'apparentTemperature': 61.13,
#                       'cloudCover': 0.09,
#                       'dewPoint': 46.75,
#                       'humidity': 0.59,
#                       'icon': 'clear-day',
#                       'ozone': 382.3,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1003.1,
#                       'summary': 'Clear',
#                       'temperature': 61.13,
#                       'time': 1652824800,
#                       'uvIndex': 1,
#                       'visibility': 10,
#                       'windBearing': 224,
#                       'windGust': 25.35,
#                       'windSpeed': 16.93},
#                      {'apparentTemperature': 59.59,
#                       'cloudCover': 0.32,
#                       'dewPoint': 46.39,
#                       'humidity': 0.62,
#                       'icon': 'partly-cloudy-day',
#                       'ozone': 382.1,
#                       'precipIntensity': 0.0005,
#                       'precipProbability': 0.01,
#                       'precipType': 'rain',
#                       'pressure': 1003.7,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 59.59,
#                       'time': 1652828400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 322,
#                       'windGust': 27.68,
#                       'windSpeed': 18.35},
#                      {'apparentTemperature': 57.35,
#                       'cloudCover': 0.45,
#                       'dewPoint': 45.62,
#                       'humidity': 0.65,
#                       'icon': 'partly-cloudy-night',
#                       'ozone': 384.7,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1005,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 57.35,
#                       'time': 1652832000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 283,
#                       'windGust': 25.86,
#                       'windSpeed': 17.26},
#                      {'apparentTemperature': 55.92,
#                       'cloudCover': 0.39,
#                       'dewPoint': 45.28,
#                       'humidity': 0.67,
#                       'icon': 'partly-cloudy-night',
#                       'ozone': 389.5,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1005.7,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 55.92,
#                       'time': 1652835600,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 275,
#                       'windGust': 25,
#                       'windSpeed': 16.74},
#                      {'apparentTemperature': 54.95,
#                       'cloudCover': 0.33,
#                       'dewPoint': 45.01,
#                       'humidity': 0.69,
#                       'icon': 'partly-cloudy-night',
#                       'ozone': 396.2,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1006.3,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 54.95,
#                       'time': 1652839200,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 274,
#                       'windGust': 25.33,
#                       'windSpeed': 16.91},
#                      {'apparentTemperature': 54.15,
#                       'cloudCover': 0.15,
#                       'dewPoint': 44.89,
#                       'humidity': 0.71,
#                       'icon': 'clear-night',
#                       'ozone': 393.9,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1006.7,
#                       'summary': 'Clear',
#                       'temperature': 54.15,
#                       'time': 1652842800,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 274,
#                       'windGust': 24.72,
#                       'windSpeed': 16.55},
#                      {'apparentTemperature': 53.63,
#                       'cloudCover': 0.16,
#                       'dewPoint': 44.94,
#                       'humidity': 0.72,
#                       'icon': 'clear-night',
#                       'ozone': 388.6,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1007.1,
#                       'summary': 'Clear',
#                       'temperature': 53.63,
#                       'time': 1652846400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 270,
#                       'windGust': 24.68,
#                       'windSpeed': 16.43},
#                      {'apparentTemperature': 53.37,
#                       'cloudCover': 0.24,
#                       'dewPoint': 44.44,
#                       'humidity': 0.72,
#                       'icon': 'clear-night',
#                       'ozone': 385.6,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1007.2,
#                       'summary': 'Clear',
#                       'temperature': 53.37,
#                       'time': 1652850000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 287,
#                       'windGust': 27.43,
#                       'windSpeed': 17.69},
#                      {'apparentTemperature': 52.87,
#                       'cloudCover': 0.32,
#                       'dewPoint': 45.18,
#                       'humidity': 0.75,
#                       'icon': 'partly-cloudy-night',
#                       'ozone': 382.9,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1007.6,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 52.87,
#                       'time': 1652853600,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 282,
#                       'windGust': 28.48,
#                       'windSpeed': 18.25},
#                      {'apparentTemperature': 52.4,
#                       'cloudCover': 0.33,
#                       'dewPoint': 44.76,
#                       'humidity': 0.75,
#                       'icon': 'partly-cloudy-night',
#                       'ozone': 381.4,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1008.2,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 52.4,
#                       'time': 1652857200,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 282,
#                       'windGust': 27.35,
#                       'windSpeed': 17.44},
#                      {'apparentTemperature': 51.94,
#                       'cloudCover': 0.32,
#                       'dewPoint': 44.26,
#                       'humidity': 0.75,
#                       'icon': 'partly-cloudy-night',
#                       'ozone': 380.2,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1008.7,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 51.94,
#                       'time': 1652860800,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 286,
#                       'windGust': 27.3,
#                       'windSpeed': 17.5},
#                      {'apparentTemperature': 51.91,
#                       'cloudCover': 0.32,
#                       'dewPoint': 43.75,
#                       'humidity': 0.74,
#                       'icon': 'partly-cloudy-night',
#                       'ozone': 379.2,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1009.3,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 51.91,
#                       'time': 1652864400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 291,
#                       'windGust': 26.51,
#                       'windSpeed': 17.43},
#                      {'apparentTemperature': 51.6,
#                       'cloudCover': 0.49,
#                       'dewPoint': 43.13,
#                       'humidity': 0.73,
#                       'icon': 'partly-cloudy-day',
#                       'ozone': 379.3,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1009.8,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 51.6,
#                       'time': 1652868000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 292,
#                       'windGust': 25.63,
#                       'windSpeed': 17.46},
#                      {'apparentTemperature': 51.87,
#                       'cloudCover': 0.21,
#                       'dewPoint': 42.35,
#                       'humidity': 0.7,
#                       'icon': 'clear-day',
#                       'ozone': 380.5,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1010.6,
#                       'summary': 'Clear',
#                       'temperature': 51.87,
#                       'time': 1652871600,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 293,
#                       'windGust': 24.05,
#                       'windSpeed': 17.44},
#                      {'apparentTemperature': 52.13,
#                       'cloudCover': 0.15,
#                       'dewPoint': 41.39,
#                       'humidity': 0.67,
#                       'icon': 'clear-day',
#                       'ozone': 380.1,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1010.9,
#                       'summary': 'Clear',
#                       'temperature': 52.13,
#                       'time': 1652875200,
#                       'uvIndex': 1,
#                       'visibility': 10,
#                       'windBearing': 298,
#                       'windGust': 21.84,
#                       'windSpeed': 17.08},
#                      {'apparentTemperature': 53.28,
#                       'cloudCover': 0.05,
#                       'dewPoint': 41.91,
#                       'humidity': 0.65,
#                       'icon': 'clear-day',
#                       'ozone': 381.7,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011.3,
#                       'summary': 'Clear',
#                       'temperature': 53.28,
#                       'time': 1652878800,
#                       'uvIndex': 3,
#                       'visibility': 10,
#                       'windBearing': 316,
#                       'windGust': 18.79,
#                       'windSpeed': 15.4},
#                      {'apparentTemperature': 54.7,
#                       'cloudCover': 0.07,
#                       'dewPoint': 42.6,
#                       'humidity': 0.64,
#                       'icon': 'clear-day',
#                       'ozone': 378.6,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011.4,
#                       'summary': 'Clear',
#                       'temperature': 54.7,
#                       'time': 1652882400,
#                       'uvIndex': 4,
#                       'visibility': 10,
#                       'windBearing': 273,
#                       'windGust': 15.51,
#                       'windSpeed': 13.07},
#                      {'apparentTemperature': 56.14,
#                       'cloudCover': 0.08,
#                       'dewPoint': 42.9,
#                       'humidity': 0.61,
#                       'icon': 'clear-day',
#                       'ozone': 374.8,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011.6,
#                       'summary': 'Clear',
#                       'temperature': 56.14,
#                       'time': 1652886000,
#                       'uvIndex': 6,
#                       'visibility': 10,
#                       'windBearing': 281,
#                       'windGust': 13,
#                       'windSpeed': 11.39},
#                      {'apparentTemperature': 57.34,
#                       'cloudCover': 0.08,
#                       'dewPoint': 42.83,
#                       'humidity': 0.58,
#                       'icon': 'clear-day',
#                       'ozone': 370.9,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011.8,
#                       'summary': 'Clear',
#                       'temperature': 57.34,
#                       'time': 1652889600,
#                       'uvIndex': 7,
#                       'visibility': 10,
#                       'windBearing': 285,
#                       'windGust': 12.33,
#                       'windSpeed': 10.87},
#                      {'apparentTemperature': 58.18,
#                       'cloudCover': 0.07,
#                       'dewPoint': 42.65,
#                       'humidity': 0.56,
#                       'icon': 'clear-day',
#                       'ozone': 369.6,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011.6,
#                       'summary': 'Clear',
#                       'temperature': 58.18,
#                       'time': 1652893200,
#                       'uvIndex': 7,
#                       'visibility': 10,
#                       'windBearing': 265,
#                       'windGust': 11.32,
#                       'windSpeed': 10.53},
#                      {'apparentTemperature': 58.11,
#                       'cloudCover': 0.07,
#                       'dewPoint': 42.75,
#                       'humidity': 0.57,
#                       'icon': 'clear-day',
#                       'ozone': 362.5,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011.5,
#                       'summary': 'Clear',
#                       'temperature': 58.11,
#                       'time': 1652896800,
#                       'uvIndex': 7,
#                       'visibility': 10,
#                       'windBearing': 259,
#                       'windGust': 15.16,
#                       'windSpeed': 12.24},
#                      {'apparentTemperature': 59.02,
#                       'cloudCover': 0.09,
#                       'dewPoint': 42.98,
#                       'humidity': 0.55,
#                       'icon': 'clear-day',
#                       'ozone': 360.7,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011.3,
#                       'summary': 'Clear',
#                       'temperature': 59.02,
#                       'time': 1652900400,
#                       'uvIndex': 5,
#                       'visibility': 10,
#                       'windBearing': 248,
#                       'windGust': 15.54,
#                       'windSpeed': 11.78},
#                      {'apparentTemperature': 59.98,
#                       'cloudCover': 0.15,
#                       'dewPoint': 43.52,
#                       'humidity': 0.54,
#                       'icon': 'clear-day',
#                       'ozone': 359,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1010.9,
#                       'summary': 'Clear',
#                       'temperature': 59.98,
#                       'time': 1652904000,
#                       'uvIndex': 3,
#                       'visibility': 10,
#                       'windBearing': 249,
#                       'windGust': 15.41,
#                       'windSpeed': 11.01},
#                      {'apparentTemperature': 60.43,
#                       'cloudCover': 0.25,
#                       'dewPoint': 44.06,
#                       'humidity': 0.55,
#                       'icon': 'clear-day',
#                       'ozone': 357.9,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1010.7,
#                       'summary': 'Clear',
#                       'temperature': 60.43,
#                       'time': 1652907600,
#                       'uvIndex': 2,
#                       'visibility': 10,
#                       'windBearing': 259,
#                       'windGust': 14.93,
#                       'windSpeed': 10.31},
#                      {'apparentTemperature': 60.12,
#                       'cloudCover': 0.33,
#                       'dewPoint': 44.59,
#                       'humidity': 0.56,
#                       'icon': 'partly-cloudy-day',
#                       'ozone': 355.8,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1010.7,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 60.12,
#                       'time': 1652911200,
#                       'uvIndex': 1,
#                       'visibility': 10,
#                       'windBearing': 283,
#                       'windGust': 14.05,
#                       'windSpeed': 9.58},
#                      {'apparentTemperature': 59.4,
#                       'cloudCover': 0.65,
#                       'dewPoint': 44.49,
#                       'humidity': 0.58,
#                       'icon': 'partly-cloudy-day',
#                       'ozone': 355.1,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011.1,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 59.4,
#                       'time': 1652914800,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 239,
#                       'windGust': 13.76,
#                       'windSpeed': 9.53},
#                      {'apparentTemperature': 58.99,
#                       'cloudCover': 0.69,
#                       'dewPoint': 43.37,
#                       'humidity': 0.56,
#                       'icon': 'partly-cloudy-night',
#                       'ozone': 358.8,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011.5,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 58.99,
#                       'time': 1652918400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 277,
#                       'windGust': 9.28,
#                       'windSpeed': 8.26},
#                      {'apparentTemperature': 57.85,
#                       'cloudCover': 0.84,
#                       'dewPoint': 42.78,
#                       'humidity': 0.57,
#                       'icon': 'partly-cloudy-night',
#                       'ozone': 356.4,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1012.2,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 57.85,
#                       'time': 1652922000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 274,
#                       'windGust': 8.29,
#                       'windSpeed': 7.51},
#                      {'apparentTemperature': 56.69,
#                       'cloudCover': 0.72,
#                       'dewPoint': 42.26,
#                       'humidity': 0.58,
#                       'icon': 'partly-cloudy-night',
#                       'ozone': 355.1,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1012.5,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 56.69,
#                       'time': 1652925600,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 297,
#                       'windGust': 6.68,
#                       'windSpeed': 6.48},
#                      {'apparentTemperature': 55.68,
#                       'cloudCover': 0.91,
#                       'dewPoint': 42.14,
#                       'humidity': 0.6,
#                       'icon': 'cloudy',
#                       'ozone': 354.4,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1012.7,
#                       'summary': 'Overcast',
#                       'temperature': 55.68,
#                       'time': 1652929200,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 294,
#                       'windGust': 5.54,
#                       'windSpeed': 5.54},
#                      {'apparentTemperature': 54.84,
#                       'cloudCover': 0.99,
#                       'dewPoint': 42.46,
#                       'humidity': 0.63,
#                       'icon': 'cloudy',
#                       'ozone': 354.8,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1012.6,
#                       'summary': 'Overcast',
#                       'temperature': 54.84,
#                       'time': 1652932800,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 313,
#                       'windGust': 5.04,
#                       'windSpeed': 5.04},
#                      {'apparentTemperature': 54.13,
#                       'cloudCover': 1,
#                       'dewPoint': 43.26,
#                       'humidity': 0.67,
#                       'icon': 'cloudy',
#                       'ozone': 355.5,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1012.3,
#                       'summary': 'Overcast',
#                       'temperature': 54.13,
#                       'time': 1652936400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 343,
#                       'windGust': 4.99,
#                       'windSpeed': 4.57},
#                      {'apparentTemperature': 53.5,
#                       'cloudCover': 0.99,
#                       'dewPoint': 44.32,
#                       'humidity': 0.71,
#                       'icon': 'cloudy',
#                       'ozone': 356.9,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1012.2,
#                       'summary': 'Overcast',
#                       'temperature': 53.5,
#                       'time': 1652940000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 32,
#                       'windGust': 6.98,
#                       'windSpeed': 5.73},
#                      {'apparentTemperature': 53.22,
#                       'cloudCover': 0.99,
#                       'dewPoint': 45.39,
#                       'humidity': 0.75,
#                       'icon': 'cloudy',
#                       'ozone': 358,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011.9,
#                       'summary': 'Overcast',
#                       'temperature': 53.22,
#                       'time': 1652943600,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 65,
#                       'windGust': 6.85,
#                       'windSpeed': 6.42},
#                      {'apparentTemperature': 53.18,
#                       'cloudCover': 0.99,
#                       'dewPoint': 46.37,
#                       'humidity': 0.78,
#                       'icon': 'cloudy',
#                       'ozone': 357.3,
#                       'precipIntensity': 0.0003,
#                       'precipProbability': 0.02,
#                       'precipType': 'rain',
#                       'pressure': 1011,
#                       'summary': 'Overcast',
#                       'temperature': 53.18,
#                       'time': 1652947200,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 98,
#                       'windGust': 7.41,
#                       'windSpeed': 7.41},
#                      {'apparentTemperature': 53.26,
#                       'cloudCover': 0.99,
#                       'dewPoint': 47.14,
#                       'humidity': 0.8,
#                       'icon': 'cloudy',
#                       'ozone': 356.8,
#                       'precipIntensity': 0.0015,
#                       'precipProbability': 0.1,
#                       'precipType': 'rain',
#                       'pressure': 1011,
#                       'summary': 'Overcast',
#                       'temperature': 53.26,
#                       'time': 1652950800,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 148,
#                       'windGust': 8.34,
#                       'windSpeed': 8.34},
#                      {'apparentTemperature': 53.1,
#                       'cloudCover': 0.99,
#                       'dewPoint': 47.91,
#                       'humidity': 0.82,
#                       'icon': 'rain',
#                       'ozone': 355.8,
#                       'precipIntensity': 0.0112,
#                       'precipProbability': 0.27,
#                       'precipType': 'rain',
#                       'pressure': 1011.1,
#                       'summary': 'Possible Light Rain',
#                       'temperature': 53.1,
#                       'time': 1652954400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 147,
#                       'windGust': 7.41,
#                       'windSpeed': 7.41},
#                      {'apparentTemperature': 52.84,
#                       'cloudCover': 0.99,
#                       'dewPoint': 48.74,
#                       'humidity': 0.86,
#                       'icon': 'rain',
#                       'ozone': 354.8,
#                       'precipIntensity': 0.0395,
#                       'precipProbability': 0.51,
#                       'precipType': 'rain',
#                       'pressure': 1011.2,
#                       'summary': 'Rain',
#                       'temperature': 52.84,
#                       'time': 1652958000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 173,
#                       'windGust': 6.42,
#                       'windSpeed': 6.42},
#                      {'apparentTemperature': 52.8,
#                       'cloudCover': 0.91,
#                       'dewPoint': 47.61,
#                       'humidity': 0.82,
#                       'icon': 'rain',
#                       'ozone': 357.4,
#                       'precipIntensity': 0.062,
#                       'precipProbability': 0.38,
#                       'precipType': 'rain',
#                       'pressure': 1011.2,
#                       'summary': 'Rain',
#                       'temperature': 52.8,
#                       'time': 1652961600,
#                       'uvIndex': 1,
#                       'visibility': 10,
#                       'windBearing': 239,
#                       'windGust': 6.98,
#                       'windSpeed': 6.98},
#                      {'apparentTemperature': 53.24,
#                       'cloudCover': 0.88,
#                       'dewPoint': 47.9,
#                       'humidity': 0.82,
#                       'icon': 'rain',
#                       'ozone': 359,
#                       'precipIntensity': 0.042,
#                       'precipProbability': 0.38,
#                       'precipType': 'rain',
#                       'pressure': 1010.8,
#                       'summary': 'Rain',
#                       'temperature': 53.24,
#                       'time': 1652965200,
#                       'uvIndex': 2,
#                       'visibility': 10,
#                       'windBearing': 176,
#                       'windGust': 8.45,
#                       'windSpeed': 8.31},
#                      {'apparentTemperature': 54.35,
#                       'cloudCover': 0.89,
#                       'dewPoint': 47.94,
#                       'humidity': 0.79,
#                       'icon': 'cloudy',
#                       'ozone': 359.3,
#                       'precipIntensity': 0.0144,
#                       'precipProbability': 0.24,
#                       'precipType': 'rain',
#                       'pressure': 1010.2,
#                       'summary': 'Overcast',
#                       'temperature': 54.35,
#                       'time': 1652968800,
#                       'uvIndex': 3,
#                       'visibility': 10,
#                       'windBearing': 146,
#                       'windGust': 10.1,
#                       'windSpeed': 9.71},
#                      {'apparentTemperature': 55.15,
#                       'cloudCover': 0.89,
#                       'dewPoint': 48.16,
#                       'humidity': 0.77,
#                       'icon': 'cloudy',
#                       'ozone': 359.1,
#                       'precipIntensity': 0.0048,
#                       'precipProbability': 0.09,
#                       'precipType': 'rain',
#                       'pressure': 1009.6,
#                       'summary': 'Overcast',
#                       'temperature': 55.15,
#                       'time': 1652972400,
#                       'uvIndex': 4,
#                       'visibility': 10,
#                       'windBearing': 174,
#                       'windGust': 14.77,
#                       'windSpeed': 12.29}],
#             'icon': 'clear-day',
#             'summary': 'Clear throughout the day.'},
#  'latitude': 43.0443,
#  'longitude': -70.4528,
#  'minutely': {'data': [{'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652801220},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652801280},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652801340},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652801400},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652801460},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652801520},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652801580},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652801640},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652801700},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652801760},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652801820},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652801880},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652801940},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652802000},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652802060},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652802120},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652802180},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652802240},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652802300},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652802360},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652802420},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652802480},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652802540},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652802600},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652802660},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652802720},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652802780},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652802840},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652802900},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652802960},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803020},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803080},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803140},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803200},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803260},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803320},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803380},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803440},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803500},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803560},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803620},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803680},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803740},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803800},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803860},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803920},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803980},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804040},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804100},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804160},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804220},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804280},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804340},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804400},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804460},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804520},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804580},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804640},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804700},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804760},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804820}],
#               'icon': 'clear-day',
#               'summary': 'Clear for the hour.'},
#  'offset': -4,
#  'timezone': 'America/New_York'}

# %% [markdown]
# ## Advanced API tools:  Requests
# * Requests - HTTP for Humans:  http://docs.python-requests.org/en/master/
# * Nice methods for each HTTP verb
# * Easy response handling for most common data formats
# * Can handle cookies, authentication, streaming downloads
# * Lots of community support for advanced usage:  OAuth, Caching, Async

# %%
import requests

# %%
# !pip3 install requests
# OR python3 -m pip install requests

# %%
import requests
response = requests.get('https://xkcd.com')
print(response.text)
print(response.headers)
print(response.status_code)

# %%
help(requests.get)

# %% [markdown]
# ## Common API Response formats

# %% [markdown]
# ## CSV (Comma-Separated Values) / Delimited text
# * One of the simplest forms of data transfer formats
# * Often simply a direct dump from a database or spreadsheet
# * Very efficient data transfer (little metadata)
# * Popular in government data sources and data science
# * Has a few problems that make it less popular on the client side
#     * No data type support - everything is a string
#     * Delimeters in text need to be handled specially (usually quoting)
#     * There are several subtley different "dialects" from various tools (no real specification)
#     * Not terribly human-readable either

# %%
import requests
import csv

# Hourly earthquake data for earthquakes over 1.0 magnitude, per USGS
response = requests.get('https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_hour.csv')
print(response.text)
# Sometimes we have to deal with different data encodings (ASCII, UTF-8, etc.)
reader = csv.DictReader(response.iter_lines(decode_unicode=True))
for row in reader:
    print(row['time'], row['place'], row['mag'])

# %% [markdown]
# ## XML (eXtensible Markup Language)
# * Became popular as the Web took off (late 1990s)
# * Intended to be very easy for humans to read (compared to binary formats)
# * Text only - once again to avoid prior binary protocols
# * No data types - everything is a string
# * Very verbose format - not great efficiency for very large files
# * Not really streamable (there are workarounds)
# * Official spec (but there are many extensions):
# * Still very popular as a configuration format (C#, Java, etc)

# %%
import requests
from xml.etree import ElementTree as ET

response = requests.get('https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_week_age_link.kml')

print(response.text)
print()
root = ET.fromstring(response.text)
print(root.tag)
document = root.find('{http://www.opengis.net/kml/2.2}Document')
for child in document:
    print(child.tag)
    print(child.text)

# %% [markdown]
# ## JSON (JavaScript Object Notation)
# * Syntax is valid, literal JavaScript objects
# * Gained rapid popularity because it is simple concise, and easy to deal with in JavaScript
# * Translates easily to Python objects
# * Still pretty human readable
# * Supports a limited set of data types (number, string, boolean, "object", and array)
# * Has an official specification:  https://www.json.org/json-en.html

# %%
import requests
from pprint import pprint
response = requests.get('https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_hour.geojson')

data = response.json()
pprint(data)
print()
for record in data['features']:
    print(record['properties']['time'], record['properties']['place'], record['properties']['mag'])
# Out:
# {'bbox': [-119.5362, -17.9676, 3.7, -69.8301, 38.5188, 138.56],
#  'features': [{'geometry': {'coordinates': [-119.5362, 38.4675, 3.7],
#                             'type': 'Point'},
#                'id': 'nn00839095',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '00839095',
#                               'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00839095.geojson',
#                               'dmin': 0.085,
#                               'felt': None,
#                               'gap': 189.1,
#                               'ids': ',nn00839095,',
#                               'mag': 1.1,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'nn',
#                               'nst': 9,
#                               'place': '7 km SW of Walker, California',
#                               'rms': 0.1145,
#                               'sig': 19,
#                               'sources': ',nn,',
#                               'status': 'automatic',
#                               'time': 1652875180986,
#                               'title': 'M 1.1 - 7 km SW of Walker, California',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',origin,phase-data,',
#                               'tz': None,
#                               'updated': 1652875385610,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00839095'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.8301, -17.9676, 138.56],
#                             'type': 'Point'},
#                'id': 'us6000hlz1',
#                'properties': {'alert': None,
#                               'cdi': 3.1,
#                               'code': '6000hlz1',
#                               'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000hlz1.geojson',
#                               'dmin': 0.477,
#                               'felt': 2,
#                               'gap': 80,
#                               'ids': ',us6000hlz1,',
#                               'mag': 4.7,
#                               'magType': 'mb',
#                               'mmi': None,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '25 km SSE of Palca, Peru',
#                               'rms': 0.82,
#                               'sig': 340,
#                               'sources': ',us,',
#                               'status': 'reviewed',
#                               'time': 1652873227551,
#                               'title': 'M 4.7 - 25 km SSE of Palca, Peru',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',dyfi,origin,phase-data,',
#                               'tz': None,
#                               'updated': 1652875111900,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000hlz1'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-119.5292, 38.5188, 5.5],
#                             'type': 'Point'},
#                'id': 'nn00839094',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '00839094',
#                               'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00839094.geojson',
#                               'dmin': 0.068,
#                               'felt': None,
#                               'gap': 176.97,
#                               'ids': ',nn00839094,',
#                               'mag': 1.1,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'nn',
#                               'nst': 8,
#                               'place': '4 km W of Walker, California',
#                               'rms': 0.093,
#                               'sig': 19,
#                               'sources': ',nn,',
#                               'status': 'automatic',
#                               'time': 1652873098961,
#                               'title': 'M 1.1 - 4 km W of Walker, California',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',origin,phase-data,',
#                               'tz': None,
#                               'updated': 1652873304816,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00839094'},
#                'type': 'Feature'}],
#  'metadata': {'api': '1.10.3',
#               'count': 3,
#               'generated': 1652875923000,
#               'status': 200,
#               'title': 'USGS Magnitude 1.0+ Earthquakes, Past Hour',
#               'url': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_hour.geojson'},
#  'type': 'FeatureCollection'}
#
# 1652875180986 7 km SW of Walker, California 1.1
# 1652873227551 25 km SSE of Palca, Peru 4.7
# 1652873098961 4 km W of Walker, California 1.1

# %% [markdown]
# ## Lab: API Requests
#
# * Using the `requests` package, and the API key above, write a function that makes a request for your own location to the DarkSky API, and print out the response data.

# %%
import requests
from pprint import pprint

def apilab():
    SECRET_KEY = '1d8c58ed1d54f96f939e706c788650f1'
    lat, long = (43.0443,-70.4528)  # Smyrna, GA
    
    url = 'https://api.darksky.net/forecast/{key}/{lat},{long}'.format(
        key=SECRET_KEY, lat=lat, long=long)
    payload={}
    headers = {}
    response = requests.request("GET", url, headers=headers, data=payload)
    data = response.json()
    print(data['currently'])
    pprint(data)
    print(data['latitude'],' ',data['longitude'] )

apilab()
# Out:
# {'currently': {'apparentTemperature': 61.9,
#                'cloudCover': 0.18,
#                'dewPoint': 48.06,
#                'humidity': 0.6,
#                'icon': 'clear-day',
#                'nearestStormBearing': 142,
#                'nearestStormDistance': 25,
#                'ozone': 382.7,
#                'precipIntensity': 0,
#                'precipProbability': 0,
#                'pressure': 1001.9,
#                'summary': 'Clear',
#                'temperature': 61.9,
#                'time': 1652811827,
#                'uvIndex': 5,
#                'visibility': 10,
#                'windBearing': 247,
#                'windGust': 27.34,
#                'windSpeed': 17.88},
#  'daily': {'data': [{'apparentTemperatureHigh': 62.55,
#                      'apparentTemperatureHighTime': 1652818320,
#                      'apparentTemperatureLow': 51.35,
#                      'apparentTemperatureLowTime': 1652869680,
#                      'apparentTemperatureMax': 62.55,
#                      'apparentTemperatureMaxTime': 1652818320,
#                      'apparentTemperatureMin': 53.59,
#                      'apparentTemperatureMinTime': 1652846400,
#                      'cloudCover': 0.26,
#                      'dewPoint': 49.27,
#                      'humidity': 0.75,
#                      'icon': 'rain',
#                      'moonPhase': 0.57,
#                      'ozone': 383.2,
#                      'precipIntensity': 0.0013,
#                      'precipIntensityMax': 0.0406,
#                      'precipIntensityMaxTime': 1652760000,
#                      'precipProbability': 0.59,
#                      'precipType': 'rain',
#                      'pressure': 1002.2,
#                      'summary': 'Clear throughout the day.',
#                      'sunriseTime': 1652779080,
#                      'sunsetTime': 1652832120,
#                      'temperatureHigh': 63.05,
#                      'temperatureHighTime': 1652818320,
#                      'temperatureLow': 50.86,
#                      'temperatureLowTime': 1652869680,
#                      'temperatureMax': 63.05,
#                      'temperatureMaxTime': 1652818320,
#                      'temperatureMin': 53.1,
#                      'temperatureMinTime': 1652846400,
#                      'time': 1652760000,
#                      'uvIndex': 7,
#                      'uvIndexTime': 1652804820,
#                      'visibility': 9.91,
#                      'windBearing': 250,
#                      'windGust': 28.32,
#                      'windGustTime': 1652760060,
#                      'windSpeed': 16.68},
#                     {'apparentTemperatureHigh': 60.14,
#                      'apparentTemperatureHighTime': 1652908680,
#                      'apparentTemperatureLow': 53.14,
#                      'apparentTemperatureLowTime': 1652958000,
#                      'apparentTemperatureMax': 60.14,
#                      'apparentTemperatureMaxTime': 1652908680,
#                      'apparentTemperatureMin': 51.35,
#                      'apparentTemperatureMinTime': 1652869680,
#                      'cloudCover': 0.27,
#                      'dewPoint': 43.25,
#                      'humidity': 0.64,
#                      'icon': 'clear-day',
#                      'moonPhase': 0.61,
#                      'ozone': 370.9,
#                      'precipIntensity': 0,
#                      'precipIntensityMax': 0,
#                      'precipProbability': 0,
#                      'pressure': 1010.7,
#                      'summary': 'Clear throughout the day.',
#                      'sunriseTime': 1652865420,
#                      'sunsetTime': 1652918580,
#                      'temperatureHigh': 60.64,
#                      'temperatureHighTime': 1652908680,
#                      'temperatureLow': 52.65,
#                      'temperatureLowTime': 1652958000,
#                      'temperatureMax': 60.64,
#                      'temperatureMaxTime': 1652908680,
#                      'temperatureMin': 50.86,
#                      'temperatureMinTime': 1652869680,
#                      'time': 1652846400,
#                      'uvIndex': 7,
#                      'uvIndexTime': 1652892300,
#                      'visibility': 10,
#                      'windBearing': 282,
#                      'windGust': 27.25,
#                      'windGustTime': 1652861160,
#                      'windSpeed': 12.65},
#                     {'apparentTemperatureHigh': 55.35,
#                      'apparentTemperatureHighTime': 1652974620,
#                      'apparentTemperatureLow': 52.18,
#                      'apparentTemperatureLowTime': 1653038100,
#                      'apparentTemperatureMax': 55.35,
#                      'apparentTemperatureMaxTime': 1652974620,
#                      'apparentTemperatureMin': 52.82,
#                      'apparentTemperatureMinTime': 1652990280,
#                      'cloudCover': 0.87,
#                      'dewPoint': 48.69,
#                      'humidity': 0.83,
#                      'icon': 'rain',
#                      'moonPhase': 0.65,
#                      'ozone': 357.9,
#                      'precipIntensity': 0.0087,
#                      'precipIntensityMax': 0.0393,
#                      'precipIntensityMaxTime': 1652961720,
#                      'precipProbability': 0.83,
#                      'precipType': 'rain',
#                      'pressure': 1008.8,
#                      'summary': 'Rain until evening.',
#                      'sunriseTime': 1652951760,
#                      'sunsetTime': 1653005040,
#                      'temperatureHigh': 55.85,
#                      'temperatureHighTime': 1652974620,
#                      'temperatureLow': 51.69,
#                      'temperatureLowTime': 1653038100,
#                      'temperatureMax': 55.85,
#                      'temperatureMaxTime': 1652974620,
#                      'temperatureMin': 52.33,
#                      'temperatureMinTime': 1652990280,
#                      'time': 1652932800,
#                      'uvIndex': 4,
#                      'uvIndexTime': 1652978460,
#                      'visibility': 10,
#                      'windBearing': 161,
#                      'windGust': 23.54,
#                      'windGustTime': 1652990280,
#                      'windSpeed': 10.87},
#                     {'apparentTemperatureHigh': 55.93,
#                      'apparentTemperatureHighTime': 1653087600,
#                      'apparentTemperatureLow': 55.93,
#                      'apparentTemperatureLowTime': 1653087600,
#                      'apparentTemperatureMax': 58.91,
#                      'apparentTemperatureMaxTime': 1653095280,
#                      'apparentTemperatureMin': 52.18,
#                      'apparentTemperatureMinTime': 1653038100,
#                      'cloudCover': 0.46,
#                      'dewPoint': 51.87,
#                      'humidity': 0.92,
#                      'icon': 'partly-cloudy-day',
#                      'moonPhase': 0.69,
#                      'ozone': 344.6,
#                      'precipIntensity': 0.0002,
#                      'precipIntensityMax': 0.0007,
#                      'precipIntensityMaxTime': 1653086220,
#                      'precipProbability': 0.06,
#                      'precipType': 'rain',
#                      'pressure': 1013.5,
#                      'summary': 'Partly cloudy throughout the day.',
#                      'sunriseTime': 1653038100,
#                      'sunsetTime': 1653091500,
#                      'temperatureHigh': 56.43,
#                      'temperatureHighTime': 1653087600,
#                      'temperatureLow': 55.12,
#                      'temperatureLowTime': 1653116460,
#                      'temperatureMax': 59.41,
#                      'temperatureMaxTime': 1653095280,
#                      'temperatureMin': 51.69,
#                      'temperatureMinTime': 1653038100,
#                      'time': 1653019200,
#                      'uvIndex': 6,
#                      'uvIndexTime': 1653067920,
#                      'visibility': 9.999,
#                      'windBearing': 164,
#                      'windGust': 35.39,
#                      'windGustTime': 1653094920,
#                      'windSpeed': 11.41},
#                     {'apparentTemperatureHigh': 65.62,
#                      'apparentTemperatureHighTime': 1653149460,
#                      'apparentTemperatureLow': 60.65,
#                      'apparentTemperatureLowTime': 1653195000,
#                      'apparentTemperatureMax': 65.62,
#                      'apparentTemperatureMaxTime': 1653149460,
#                      'apparentTemperatureMin': 56.04,
#                      'apparentTemperatureMinTime': 1653116340,
#                      'cloudCover': 0.69,
#                      'dewPoint': 59.17,
#                      'humidity': 0.96,
#                      'icon': 'partly-cloudy-day',
#                      'moonPhase': 0.72,
#                      'ozone': 336.5,
#                      'precipIntensity': 0.0029,
#                      'precipIntensityMax': 0.0092,
#                      'precipIntensityMaxTime': 1653130020,
#                      'precipProbability': 0.33,
#                      'precipType': 'rain',
#                      'pressure': 1013.6,
#                      'summary': 'Mostly cloudy throughout the day.',
#                      'sunriseTime': 1653124440,
#                      'sunsetTime': 1653177960,
#                      'temperatureHigh': 65.51,
#                      'temperatureHighTime': 1653149520,
#                      'temperatureLow': 59.82,
#                      'temperatureLowTime': 1653194940,
#                      'temperatureMax': 65.51,
#                      'temperatureMaxTime': 1653149520,
#                      'temperatureMin': 55.12,
#                      'temperatureMinTime': 1653116460,
#                      'time': 1653105600,
#                      'uvIndex': 5,
#                      'uvIndexTime': 1653149700,
#                      'visibility': 10,
#                      'windBearing': 176,
#                      'windGust': 32.4,
#                      'windGustTime': 1653112680,
#                      'windSpeed': 14.91},
#                     {'apparentTemperatureHigh': 63.22,
#                      'apparentTemperatureHighTime': 1653238980,
#                      'apparentTemperatureLow': 56.62,
#                      'apparentTemperatureLowTime': 1653277860,
#                      'apparentTemperatureMax': 63.22,
#                      'apparentTemperatureMaxTime': 1653238980,
#                      'apparentTemperatureMin': 56.62,
#                      'apparentTemperatureMinTime': 1653277860,
#                      'cloudCover': 0.42,
#                      'dewPoint': 59.32,
#                      'humidity': 0.94,
#                      'icon': 'wind',
#                      'moonPhase': 0.76,
#                      'ozone': 330.6,
#                      'precipIntensity': 0.0031,
#                      'precipIntensityMax': 0.0122,
#                      'precipIntensityMaxTime': 1653242580,
#                      'precipProbability': 0.37,
#                      'precipType': 'rain',
#                      'pressure': 1012.3,
#                      'summary': 'Windy in the afternoon and evening.',
#                      'sunriseTime': 1653210780,
#                      'sunsetTime': 1653264420,
#                      'temperatureHigh': 63.42,
#                      'temperatureHighTime': 1653239100,
#                      'temperatureLow': 56.13,
#                      'temperatureLowTime': 1653277860,
#                      'temperatureMax': 63.6,
#                      'temperatureMaxTime': 1653199860,
#                      'temperatureMin': 56.13,
#                      'temperatureMinTime': 1653277860,
#                      'time': 1653192000,
#                      'uvIndex': 7,
#                      'uvIndexTime': 1653236220,
#                      'visibility': 9.71,
#                      'windBearing': 189,
#                      'windGust': 46.32,
#                      'windGustTime': 1653253560,
#                      'windSpeed': 15.19},
#                     {'apparentTemperatureHigh': 59.24,
#                      'apparentTemperatureHighTime': 1653317280,
#                      'apparentTemperatureLow': 54.85,
#                      'apparentTemperatureLowTime': 1653362040,
#                      'apparentTemperatureMax': 59.24,
#                      'apparentTemperatureMaxTime': 1653317280,
#                      'apparentTemperatureMin': 54.85,
#                      'apparentTemperatureMinTime': 1653362040,
#                      'cloudCover': 0.64,
#                      'dewPoint': 53.64,
#                      'humidity': 0.88,
#                      'icon': 'partly-cloudy-day',
#                      'moonPhase': 0.79,
#                      'ozone': 338.6,
#                      'precipIntensity': 0.0001,
#                      'precipIntensityMax': 0.0023,
#                      'precipIntensityMaxTime': 1653278400,
#                      'precipProbability': 0.16,
#                      'precipType': 'rain',
#                      'pressure': 1022.4,
#                      'summary': 'Partly cloudy throughout the day.',
#                      'sunriseTime': 1653297120,
#                      'sunsetTime': 1653350880,
#                      'temperatureHigh': 59.74,
#                      'temperatureHighTime': 1653317280,
#                      'temperatureLow': 54.36,
#                      'temperatureLowTime': 1653362040,
#                      'temperatureMax': 59.74,
#                      'temperatureMaxTime': 1653317280,
#                      'temperatureMin': 54.36,
#                      'temperatureMinTime': 1653362040,
#                      'time': 1653278400,
#                      'uvIndex': 7,
#                      'uvIndexTime': 1653324060,
#                      'visibility': 10,
#                      'windBearing': 306,
#                      'windGust': 32.3,
#                      'windGustTime': 1653287340,
#                      'windSpeed': 8.33},
#                     {'apparentTemperatureHigh': 56.3,
#                      'apparentTemperatureHighTime': 1653402240,
#                      'apparentTemperatureLow': 53.94,
#                      'apparentTemperatureLowTime': 1653465240,
#                      'apparentTemperatureMax': 56.3,
#                      'apparentTemperatureMaxTime': 1653402240,
#                      'apparentTemperatureMin': 54.66,
#                      'apparentTemperatureMinTime': 1653451200,
#                      'cloudCover': 0.73,
#                      'dewPoint': 50.1,
#                      'humidity': 0.82,
#                      'icon': 'partly-cloudy-day',
#                      'moonPhase': 0.83,
#                      'ozone': 344.6,
#                      'precipIntensity': 0,
#                      'precipIntensityMax': 0,
#                      'precipProbability': 0,
#                      'pressure': 1028.3,
#                      'summary': 'Mostly cloudy throughout the day.',
#                      'sunriseTime': 1653383520,
#                      'sunsetTime': 1653437340,
#                      'temperatureHigh': 56.8,
#                      'temperatureHighTime': 1653402240,
#                      'temperatureLow': 53.45,
#                      'temperatureLowTime': 1653465240,
#                      'temperatureMax': 56.8,
#                      'temperatureMaxTime': 1653402240,
#                      'temperatureMin': 54.17,
#                      'temperatureMinTime': 1653451200,
#                      'time': 1653364800,
#                      'uvIndex': 5,
#                      'uvIndexTime': 1653413220,
#                      'visibility': 10,
#                      'windBearing': 65,
#                      'windGust': 24.98,
#                      'windGustTime': 1653443820,
#                      'windSpeed': 8.23}],
#            'icon': 'rain',
#            'summary': 'Rain today and Thursday.'},
#  'flags': {'nearest-station': 9.438,
#            'sources': ['nwspa',
#                        'cmc',
#                        'gfs',
#                        'hrrr',
#                        'icon',
#                        'isd',
#                        'madis',
#                        'nam',
#                        'sref',
#                        'darksky',
#                        'nearest-precip'],
#            'units': 'us'},
#  'hourly': {'data': [{'apparentTemperature': 61.66,
#                       'cloudCover': 0.18,
#                       'dewPoint': 48.12,
#                       'humidity': 0.61,
#                       'icon': 'clear-day',
#                       'ozone': 383.1,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1001.9,
#                       'summary': 'Clear',
#                       'temperature': 61.66,
#                       'time': 1652810400,
#                       'uvIndex': 6,
#                       'visibility': 10,
#                       'windBearing': 247,
#                       'windGust': 27.02,
#                       'windSpeed': 17.75},
#                      {'apparentTemperature': 62.14,
#                       'cloudCover': 0.16,
#                       'dewPoint': 48.02,
#                       'humidity': 0.6,
#                       'icon': 'clear-day',
#                       'ozone': 382.7,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1001.9,
#                       'summary': 'Clear',
#                       'temperature': 62.14,
#                       'time': 1652814000,
#                       'uvIndex': 5,
#                       'visibility': 10,
#                       'windBearing': 248,
#                       'windGust': 27.33,
#                       'windSpeed': 17.79},
#                      {'apparentTemperature': 62.54,
#                       'cloudCover': 0.17,
#                       'dewPoint': 47.49,
#                       'humidity': 0.58,
#                       'icon': 'clear-day',
#                       'ozone': 382.4,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1001.9,
#                       'summary': 'Clear',
#                       'temperature': 62.54,
#                       'time': 1652817600,
#                       'uvIndex': 3,
#                       'visibility': 10,
#                       'windBearing': 262,
#                       'windGust': 27.51,
#                       'windSpeed': 17.57},
#                      {'apparentTemperature': 62.33,
#                       'cloudCover': 0.23,
#                       'dewPoint': 46.87,
#                       'humidity': 0.57,
#                       'icon': 'clear-day',
#                       'ozone': 383,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1002.4,
#                       'summary': 'Clear',
#                       'temperature': 62.33,
#                       'time': 1652821200,
#                       'uvIndex': 2,
#                       'visibility': 10,
#                       'windBearing': 259,
#                       'windGust': 26.28,
#                       'windSpeed': 17.1},
#                      {'apparentTemperature': 61.32,
#                       'cloudCover': 0.21,
#                       'dewPoint': 46.54,
#                       'humidity': 0.58,
#                       'icon': 'clear-day',
#                       'ozone': 383.5,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1002.9,
#                       'summary': 'Clear',
#                       'temperature': 61.32,
#                       'time': 1652824800,
#                       'uvIndex': 1,
#                       'visibility': 10,
#                       'windBearing': 217,
#                       'windGust': 24.71,
#                       'windSpeed': 16.62},
#                      {'apparentTemperature': 59.76,
#                       'cloudCover': 0.35,
#                       'dewPoint': 46.18,
#                       'humidity': 0.61,
#                       'icon': 'partly-cloudy-day',
#                       'ozone': 384,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1003.8,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 59.76,
#                       'time': 1652828400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 329,
#                       'windGust': 26.39,
#                       'windSpeed': 17.56},
#                      {'apparentTemperature': 57.3,
#                       'cloudCover': 0.54,
#                       'dewPoint': 45.51,
#                       'humidity': 0.65,
#                       'icon': 'partly-cloudy-night',
#                       'ozone': 387.9,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1004.9,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 57.3,
#                       'time': 1652832000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 287,
#                       'windGust': 21.53,
#                       'windSpeed': 15.5},
#                      {'apparentTemperature': 55.98,
#                       'cloudCover': 0.23,
#                       'dewPoint': 45.17,
#                       'humidity': 0.67,
#                       'icon': 'clear-night',
#                       'ozone': 395.1,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1005.8,
#                       'summary': 'Clear',
#                       'temperature': 55.98,
#                       'time': 1652835600,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 277,
#                       'windGust': 22.84,
#                       'windSpeed': 15.61},
#                      {'apparentTemperature': 55.03,
#                       'cloudCover': 0.18,
#                       'dewPoint': 44.89,
#                       'humidity': 0.69,
#                       'icon': 'clear-night',
#                       'ozone': 393.9,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1006.3,
#                       'summary': 'Clear',
#                       'temperature': 55.03,
#                       'time': 1652839200,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 274,
#                       'windGust': 24.47,
#                       'windSpeed': 16.34},
#                      {'apparentTemperature': 54.2,
#                       'cloudCover': 0.25,
#                       'dewPoint': 44.82,
#                       'humidity': 0.71,
#                       'icon': 'clear-night',
#                       'ozone': 387.2,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1006.7,
#                       'summary': 'Clear',
#                       'temperature': 54.2,
#                       'time': 1652842800,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 274,
#                       'windGust': 25.25,
#                       'windSpeed': 16.93},
#                      {'apparentTemperature': 53.59,
#                       'cloudCover': 0.09,
#                       'dewPoint': 44.92,
#                       'humidity': 0.72,
#                       'icon': 'clear-night',
#                       'ozone': 385,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1007,
#                       'summary': 'Clear',
#                       'temperature': 53.59,
#                       'time': 1652846400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 272,
#                       'windGust': 25.05,
#                       'windSpeed': 16.66},
#                      {'apparentTemperature': 53.08,
#                       'cloudCover': 0.12,
#                       'dewPoint': 45.13,
#                       'humidity': 0.74,
#                       'icon': 'clear-night',
#                       'ozone': 382.8,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1007.3,
#                       'summary': 'Clear',
#                       'temperature': 53.08,
#                       'time': 1652850000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 287,
#                       'windGust': 24.72,
#                       'windSpeed': 16.2},
#                      {'apparentTemperature': 52.65,
#                       'cloudCover': 0.23,
#                       'dewPoint': 45.88,
#                       'humidity': 0.78,
#                       'icon': 'clear-night',
#                       'ozone': 381,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1007.7,
#                       'summary': 'Clear',
#                       'temperature': 52.65,
#                       'time': 1652853600,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 280,
#                       'windGust': 24.82,
#                       'windSpeed': 16.49},
#                      {'apparentTemperature': 52.21,
#                       'cloudCover': 0.45,
#                       'dewPoint': 44.85,
#                       'humidity': 0.76,
#                       'icon': 'partly-cloudy-night',
#                       'ozone': 379.4,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1008.2,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 52.21,
#                       'time': 1652857200,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 284,
#                       'windGust': 25.85,
#                       'windSpeed': 16.6},
#                      {'apparentTemperature': 51.74,
#                       'cloudCover': 0.39,
#                       'dewPoint': 43.94,
#                       'humidity': 0.75,
#                       'icon': 'partly-cloudy-night',
#                       'ozone': 377.5,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1008.6,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 51.74,
#                       'time': 1652860800,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 285,
#                       'windGust': 27.23,
#                       'windSpeed': 17.26},
#                      {'apparentTemperature': 51.52,
#                       'cloudCover': 0.29,
#                       'dewPoint': 43.58,
#                       'humidity': 0.74,
#                       'icon': 'clear-night',
#                       'ozone': 376.8,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1009.2,
#                       'summary': 'Clear',
#                       'temperature': 51.52,
#                       'time': 1652864400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 290,
#                       'windGust': 26.59,
#                       'windSpeed': 17.46},
#                      {'apparentTemperature': 51.37,
#                       'cloudCover': 0.28,
#                       'dewPoint': 42.94,
#                       'humidity': 0.73,
#                       'icon': 'clear-day',
#                       'ozone': 377.4,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1009.7,
#                       'summary': 'Clear',
#                       'temperature': 51.37,
#                       'time': 1652868000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 292,
#                       'windGust': 25.95,
#                       'windSpeed': 17.85},
#                      {'apparentTemperature': 51.41,
#                       'cloudCover': 0.2,
#                       'dewPoint': 42.26,
#                       'humidity': 0.71,
#                       'icon': 'clear-day',
#                       'ozone': 376.5,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1010.4,
#                       'summary': 'Clear',
#                       'temperature': 51.41,
#                       'time': 1652871600,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 292,
#                       'windGust': 24.71,
#                       'windSpeed': 17.97},
#                      {'apparentTemperature': 51.91,
#                       'cloudCover': 0.17,
#                       'dewPoint': 41.4,
#                       'humidity': 0.67,
#                       'icon': 'clear-day',
#                       'ozone': 378.1,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1010.9,
#                       'summary': 'Clear',
#                       'temperature': 51.91,
#                       'time': 1652875200,
#                       'uvIndex': 1,
#                       'visibility': 10,
#                       'windBearing': 297,
#                       'windGust': 22.68,
#                       'windSpeed': 17.64},
#                      {'apparentTemperature': 53.11,
#                       'cloudCover': 0.08,
#                       'dewPoint': 41.99,
#                       'humidity': 0.66,
#                       'icon': 'clear-day',
#                       'ozone': 379.3,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011.4,
#                       'summary': 'Clear',
#                       'temperature': 53.11,
#                       'time': 1652878800,
#                       'uvIndex': 3,
#                       'visibility': 10,
#                       'windBearing': 316,
#                       'windGust': 19.93,
#                       'windSpeed': 15.79},
#                      {'apparentTemperature': 54.69,
#                       'cloudCover': 0.08,
#                       'dewPoint': 42.56,
#                       'humidity': 0.64,
#                       'icon': 'clear-day',
#                       'ozone': 377.8,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011.5,
#                       'summary': 'Clear',
#                       'temperature': 54.69,
#                       'time': 1652882400,
#                       'uvIndex': 4,
#                       'visibility': 10,
#                       'windBearing': 277,
#                       'windGust': 16.96,
#                       'windSpeed': 13.55},
#                      {'apparentTemperature': 56.18,
#                       'cloudCover': 0.08,
#                       'dewPoint': 42.79,
#                       'humidity': 0.61,
#                       'icon': 'clear-day',
#                       'ozone': 374.5,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011.6,
#                       'summary': 'Clear',
#                       'temperature': 56.18,
#                       'time': 1652886000,
#                       'uvIndex': 6,
#                       'visibility': 10,
#                       'windBearing': 286,
#                       'windGust': 14.23,
#                       'windSpeed': 11.79},
#                      {'apparentTemperature': 57.39,
#                       'cloudCover': 0.08,
#                       'dewPoint': 42.82,
#                       'humidity': 0.58,
#                       'icon': 'clear-day',
#                       'ozone': 373.1,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011.7,
#                       'summary': 'Clear',
#                       'temperature': 57.39,
#                       'time': 1652889600,
#                       'uvIndex': 7,
#                       'visibility': 10,
#                       'windBearing': 290,
#                       'windGust': 12.59,
#                       'windSpeed': 10.87},
#                      {'apparentTemperature': 58.12,
#                       'cloudCover': 0.07,
#                       'dewPoint': 42.63,
#                       'humidity': 0.56,
#                       'icon': 'clear-day',
#                       'ozone': 371.4,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011.6,
#                       'summary': 'Clear',
#                       'temperature': 58.12,
#                       'time': 1652893200,
#                       'uvIndex': 7,
#                       'visibility': 10,
#                       'windBearing': 269,
#                       'windGust': 10.99,
#                       'windSpeed': 10.28},
#                      {'apparentTemperature': 58.07,
#                       'cloudCover': 0.07,
#                       'dewPoint': 42.71,
#                       'humidity': 0.57,
#                       'icon': 'clear-day',
#                       'ozone': 367.3,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011.7,
#                       'summary': 'Clear',
#                       'temperature': 58.07,
#                       'time': 1652896800,
#                       'uvIndex': 6,
#                       'visibility': 10,
#                       'windBearing': 262,
#                       'windGust': 14.57,
#                       'windSpeed': 11.78},
#                      {'apparentTemperature': 58.86,
#                       'cloudCover': 0.07,
#                       'dewPoint': 42.8,
#                       'humidity': 0.55,
#                       'icon': 'clear-day',
#                       'ozone': 367.1,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011.5,
#                       'summary': 'Clear',
#                       'temperature': 58.86,
#                       'time': 1652900400,
#                       'uvIndex': 5,
#                       'visibility': 10,
#                       'windBearing': 253,
#                       'windGust': 15.02,
#                       'windSpeed': 11.34},
#                      {'apparentTemperature': 59.75,
#                       'cloudCover': 0.09,
#                       'dewPoint': 43.33,
#                       'humidity': 0.55,
#                       'icon': 'clear-day',
#                       'ozone': 364.2,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011,
#                       'summary': 'Clear',
#                       'temperature': 59.75,
#                       'time': 1652904000,
#                       'uvIndex': 3,
#                       'visibility': 10,
#                       'windBearing': 246,
#                       'windGust': 15,
#                       'windSpeed': 10.65},
#                      {'apparentTemperature': 60.12,
#                       'cloudCover': 0.12,
#                       'dewPoint': 43.9,
#                       'humidity': 0.55,
#                       'icon': 'clear-day',
#                       'ozone': 363,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1010.7,
#                       'summary': 'Clear',
#                       'temperature': 60.12,
#                       'time': 1652907600,
#                       'uvIndex': 2,
#                       'visibility': 10,
#                       'windBearing': 259,
#                       'windGust': 14.56,
#                       'windSpeed': 10.01},
#                      {'apparentTemperature': 59.99,
#                       'cloudCover': 0.14,
#                       'dewPoint': 44.3,
#                       'humidity': 0.56,
#                       'icon': 'clear-day',
#                       'ozone': 362.2,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1010.9,
#                       'summary': 'Clear',
#                       'temperature': 59.99,
#                       'time': 1652911200,
#                       'uvIndex': 1,
#                       'visibility': 10,
#                       'windBearing': 281,
#                       'windGust': 14.43,
#                       'windSpeed': 9.67},
#                      {'apparentTemperature': 59.23,
#                       'cloudCover': 0.18,
#                       'dewPoint': 44.27,
#                       'humidity': 0.58,
#                       'icon': 'clear-day',
#                       'ozone': 359.5,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011.3,
#                       'summary': 'Clear',
#                       'temperature': 59.23,
#                       'time': 1652914800,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 238,
#                       'windGust': 14.11,
#                       'windSpeed': 9.56},
#                      {'apparentTemperature': 58.93,
#                       'cloudCover': 0.48,
#                       'dewPoint': 43.24,
#                       'humidity': 0.56,
#                       'icon': 'partly-cloudy-night',
#                       'ozone': 363.2,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011.9,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 58.93,
#                       'time': 1652918400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 277,
#                       'windGust': 10.22,
#                       'windSpeed': 8.66},
#                      {'apparentTemperature': 57.66,
#                       'cloudCover': 0.66,
#                       'dewPoint': 42.61,
#                       'humidity': 0.57,
#                       'icon': 'partly-cloudy-night',
#                       'ozone': 360.3,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1012.5,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 57.66,
#                       'time': 1652922000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 276,
#                       'windGust': 9.18,
#                       'windSpeed': 7.93},
#                      {'apparentTemperature': 56.46,
#                       'cloudCover': 0.8,
#                       'dewPoint': 42.18,
#                       'humidity': 0.59,
#                       'icon': 'partly-cloudy-night',
#                       'ozone': 358.4,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1012.8,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 56.46,
#                       'time': 1652925600,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 299,
#                       'windGust': 7.6,
#                       'windSpeed': 6.95},
#                      {'apparentTemperature': 55.38,
#                       'cloudCover': 0.9,
#                       'dewPoint': 42.15,
#                       'humidity': 0.61,
#                       'icon': 'cloudy',
#                       'ozone': 357.9,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1013.1,
#                       'summary': 'Overcast',
#                       'temperature': 55.38,
#                       'time': 1652929200,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 299,
#                       'windGust': 7.03,
#                       'windSpeed': 6.3},
#                      {'apparentTemperature': 54.53,
#                       'cloudCover': 0.94,
#                       'dewPoint': 42.78,
#                       'humidity': 0.64,
#                       'icon': 'cloudy',
#                       'ozone': 359,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1013,
#                       'summary': 'Overcast',
#                       'temperature': 54.53,
#                       'time': 1652932800,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 321,
#                       'windGust': 5.8,
#                       'windSpeed': 5.35},
#                      {'apparentTemperature': 53.91,
#                       'cloudCover': 0.94,
#                       'dewPoint': 43.7,
#                       'humidity': 0.68,
#                       'icon': 'cloudy',
#                       'ozone': 358.8,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1012.8,
#                       'summary': 'Overcast',
#                       'temperature': 53.91,
#                       'time': 1652936400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 14,
#                       'windGust': 5.01,
#                       'windSpeed': 4.6},
#                      {'apparentTemperature': 53.49,
#                       'cloudCover': 0.94,
#                       'dewPoint': 44.72,
#                       'humidity': 0.72,
#                       'icon': 'cloudy',
#                       'ozone': 359.5,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1012.5,
#                       'summary': 'Overcast',
#                       'temperature': 53.49,
#                       'time': 1652940000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 88,
#                       'windGust': 6.52,
#                       'windSpeed': 4.95},
#                      {'apparentTemperature': 53.32,
#                       'cloudCover': 0.98,
#                       'dewPoint': 45.42,
#                       'humidity': 0.75,
#                       'icon': 'cloudy',
#                       'ozone': 359.8,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1012.3,
#                       'summary': 'Overcast',
#                       'temperature': 53.32,
#                       'time': 1652943600,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 113,
#                       'windGust': 6.38,
#                       'windSpeed': 5.65},
#                      {'apparentTemperature': 53.33,
#                       'cloudCover': 0.99,
#                       'dewPoint': 46.09,
#                       'humidity': 0.76,
#                       'icon': 'cloudy',
#                       'ozone': 358.9,
#                       'precipIntensity': 0.0003,
#                       'precipProbability': 0.01,
#                       'precipType': 'rain',
#                       'pressure': 1011.5,
#                       'summary': 'Overcast',
#                       'temperature': 53.33,
#                       'time': 1652947200,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 118,
#                       'windGust': 7.36,
#                       'windSpeed': 6.87},
#                      {'apparentTemperature': 53.39,
#                       'cloudCover': 0.98,
#                       'dewPoint': 46.9,
#                       'humidity': 0.79,
#                       'icon': 'cloudy',
#                       'ozone': 355.9,
#                       'precipIntensity': 0.0015,
#                       'precipProbability': 0.07,
#                       'precipType': 'rain',
#                       'pressure': 1011.5,
#                       'summary': 'Overcast',
#                       'temperature': 53.39,
#                       'time': 1652950800,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 127,
#                       'windGust': 8.52,
#                       'windSpeed': 8.05},
#                      {'apparentTemperature': 53.27,
#                       'cloudCover': 1,
#                       'dewPoint': 47.94,
#                       'humidity': 0.82,
#                       'icon': 'cloudy',
#                       'ozone': 353.8,
#                       'precipIntensity': 0.0082,
#                       'precipProbability': 0.24,
#                       'precipType': 'rain',
#                       'pressure': 1011.7,
#                       'summary': 'Overcast',
#                       'temperature': 53.27,
#                       'time': 1652954400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 149,
#                       'windGust': 8.49,
#                       'windSpeed': 8.13},
#                      {'apparentTemperature': 53.14,
#                       'cloudCover': 0.99,
#                       'dewPoint': 49.18,
#                       'humidity': 0.86,
#                       'icon': 'rain',
#                       'ozone': 353.2,
#                       'precipIntensity': 0.0257,
#                       'precipProbability': 0.43,
#                       'precipType': 'rain',
#                       'pressure': 1011.8,
#                       'summary': 'Possible Light Rain',
#                       'temperature': 53.14,
#                       'time': 1652958000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 155,
#                       'windGust': 7.88,
#                       'windSpeed': 7.72},
#                      {'apparentTemperature': 52.94,
#                       'cloudCover': 0.92,
#                       'dewPoint': 48.57,
#                       'humidity': 0.85,
#                       'icon': 'rain',
#                       'ozone': 357.4,
#                       'precipIntensity': 0.0393,
#                       'precipProbability': 0.32,
#                       'precipType': 'rain',
#                       'pressure': 1011.8,
#                       'summary': 'Rain',
#                       'temperature': 52.94,
#                       'time': 1652961600,
#                       'uvIndex': 1,
#                       'visibility': 10,
#                       'windBearing': 177,
#                       'windGust': 9.73,
#                       'windSpeed': 8.31},
#                      {'apparentTemperature': 53.47,
#                       'cloudCover': 0.88,
#                       'dewPoint': 48.63,
#                       'humidity': 0.84,
#                       'icon': 'rain',
#                       'ozone': 357.7,
#                       'precipIntensity': 0.0283,
#                       'precipProbability': 0.32,
#                       'precipType': 'rain',
#                       'pressure': 1011.2,
#                       'summary': 'Possible Light Rain',
#                       'temperature': 53.47,
#                       'time': 1652965200,
#                       'uvIndex': 2,
#                       'visibility': 10,
#                       'windBearing': 155,
#                       'windGust': 9.93,
#                       'windSpeed': 8.93},
#                      {'apparentTemperature': 54.38,
#                       'cloudCover': 0.85,
#                       'dewPoint': 48.39,
#                       'humidity': 0.8,
#                       'icon': 'partly-cloudy-day',
#                       'ozone': 357.2,
#                       'precipIntensity': 0.0113,
#                       'precipProbability': 0.19,
#                       'precipType': 'rain',
#                       'pressure': 1010.4,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 54.38,
#                       'time': 1652968800,
#                       'uvIndex': 3,
#                       'visibility': 10,
#                       'windBearing': 149,
#                       'windGust': 12.78,
#                       'windSpeed': 11.06},
#                      {'apparentTemperature': 55.22,
#                       'cloudCover': 0.87,
#                       'dewPoint': 48.17,
#                       'humidity': 0.77,
#                       'icon': 'partly-cloudy-day',
#                       'ozone': 358.1,
#                       'precipIntensity': 0.0059,
#                       'precipProbability': 0.11,
#                       'precipType': 'rain',
#                       'pressure': 1009.6,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 55.22,
#                       'time': 1652972400,
#                       'uvIndex': 4,
#                       'visibility': 10,
#                       'windBearing': 175,
#                       'windGust': 14.9,
#                       'windSpeed': 12.62},
#                      {'apparentTemperature': 55.32,
#                       'cloudCover': 0.89,
#                       'dewPoint': 48.28,
#                       'humidity': 0.77,
#                       'icon': 'cloudy',
#                       'ozone': 358.1,
#                       'precipIntensity': 0.0034,
#                       'precipProbability': 0.07,
#                       'precipType': 'rain',
#                       'pressure': 1008.7,
#                       'summary': 'Overcast',
#                       'temperature': 55.32,
#                       'time': 1652976000,
#                       'uvIndex': 4,
#                       'visibility': 10,
#                       'windBearing': 180,
#                       'windGust': 16.9,
#                       'windSpeed': 14.28},
#                      {'apparentTemperature': 54.9,
#                       'cloudCover': 0.89,
#                       'dewPoint': 48.62,
#                       'humidity': 0.79,
#                       'icon': 'cloudy',
#                       'ozone': 357.7,
#                       'precipIntensity': 0.0052,
#                       'precipProbability': 0.14,
#                       'precipType': 'rain',
#                       'pressure': 1007.8,
#                       'summary': 'Overcast',
#                       'temperature': 54.9,
#                       'time': 1652979600,
#                       'uvIndex': 4,
#                       'visibility': 10,
#                       'windBearing': 170,
#                       'windGust': 20.77,
#                       'windSpeed': 16.72},
#                      {'apparentTemperature': 53.57,
#                       'cloudCover': 0.99,
#                       'dewPoint': 49.74,
#                       'humidity': 0.87,
#                       'icon': 'rain',
#                       'ozone': 356.2,
#                       'precipIntensity': 0.0157,
#                       'precipProbability': 0.4,
#                       'precipType': 'rain',
#                       'pressure': 1007.1,
#                       'summary': 'Possible Light Rain',
#                       'temperature': 53.57,
#                       'time': 1652983200,
#                       'uvIndex': 4,
#                       'visibility': 10,
#                       'windBearing': 168,
#                       'windGust': 22.2,
#                       'windSpeed': 17.94}],
#             'icon': 'clear-day',
#             'summary': 'Clear throughout the day.'},
#  'latitude': 43.0443,
#  'longitude': -70.4528,
#  'minutely': {'data': [{'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652811780},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652811840},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652811900},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652811960},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652812020},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652812080},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652812140},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652812200},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652812260},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652812320},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652812380},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652812440},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652812500},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652812560},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652812620},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652812680},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652812740},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652812800},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652812860},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652812920},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652812980},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652813040},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652813100},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652813160},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652813220},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652813280},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652813340},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652813400},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652813460},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652813520},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652813580},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652813640},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652813700},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652813760},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652813820},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652813880},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652813940},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652814000},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652814060},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652814120},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652814180},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652814240},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652814300},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652814360},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652814420},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652814480},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652814540},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652814600},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652814660},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652814720},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652814780},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652814840},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652814900},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652814960},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652815020},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652815080},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652815140},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652815200},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652815260},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652815320},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652815380}],
#               'icon': 'clear-day',
#               'summary': 'Clear for the hour.'},
#  'offset': -4,
#  'timezone': 'America/New_York'}
# 43.0443   -70.4528

# %% [markdown]
# ## Other API concerns
# * Not all APIs are RESTful - you may need to deal with a proprietary protocol or simply request files
# * Authorization - many APIs require keys, tokens, or other credentials
# * Network outages
# * Rate limiting, tiering of access

# %% [markdown]
# ## But what if the site or web app doesn't offer an API?

# %% [markdown]
# # Web Scraping
#
# ### Requesting web pages built to render displays for HUMANS and extracting the information we want

# %% [markdown]
# ## Why should web scraping be a fallback?
# * More manual trial and error up front
# * Pages meant for humans may change frequently for any reason
# * Pages meant for display may have data scattered or buried
# * Popularity of Javascript frameworks may make data even harder to find

# %% [markdown]
# ## BeautifulSoup - Python package for parsing HTML
# * Offers support for various parsers (html, xml, lxml)
# * Provides easy methods and properties for navigating the markup "tree"
# * Search by HTML tags, attributes, CSS class, etc.
# * Regular expression support

# %%
import requests
import bs4

response = requests.get('https://cnn.com')
soup = bs4.BeautifulSoup(response.text)
soup

# %%
soup.title

# %%
soup.body.div

# %%
for child in soup.body.children:
    print(child)

# %%
soup.find_all('a')

# %% [markdown]
# ## That's a mess - but sometimes we can cheat a little...

# %%
response = requests.get('http://rss.cnn.com/rss/cnn_topstories.rss')
soup = bs4.BeautifulSoup(response.text)

soup.rss.find_all('title')

# %%
headlines = [node.string for node in soup.rss.find_all('title')]
headlines

# %% [markdown]
# ## Bonus Lab:  Web Scraping
#
# Using BeautifulSoup4, scrap the Wikipedia page for the History Python to obtain the following information:
# * What is the sum total length of support time for each major version of Python (i.e. 0.x, 1.x, 2.x, 3.x)
# * How much time was each major version supported after the next major version appeared?
# * Display the list of the final version for each major version

# %% [markdown]
# ## Python and Databases

# %% [markdown]
# ## DBAPI2:  The Python way to handle databases
#
# DBAPI2 is an API specification (https://www.python.org/dev/peps/pep-0249/) that defines a set of Python objects that are available when querying database engines.  While there are a very large number of database engines, and several database connectivity standards (ODBC, JDBC, etc), the DBAPI2 objects are what you see on the Python side.
#
# DBAPI2 **is**:
# * A common interface in Python that makes it simpler to switch databases
# * Provided by Python database driver packages
# * Simple and straightforward
#
# DBAPI2 **is not**:
# * A translation layer for SQL queries
# * An Object-Relational Mapper
# * A Python implementation of any database-specific features

# %% [markdown]
# ## `sqlite3` - The built-in database
# * Open-source database engine
# * Simple file-based storage
# * Great for prototyping
# * SQL compliant (almost)
# * Does NOT support parallel access (don't put it in production web apps!)

# %%
query = """
CREATE TABLE users (user_id INTEGER, username TEXT, email TEXT, pto_days REAL)
"""

# %%
import sqlite3

# "Connect" to the database
conn = sqlite3.connect('example.db')

# Get a cursor from the connection
cursor = conn.cursor()

# Execute a SQL query
cursor.execute(query)

# Inspect the results, if any
result = cursor.fetchone()
print(result)


# Commit the changes
conn.commit()
# Close the connection
conn.close()

# %%
# !ls -al *.db

# %%
insert_query = """
INSERT INTO users
VALUES
(1, "jrrickerson", "jrrickerson@redrivetstudios.com", 15.0),
(2, "dave", "dws@developintelligence.com", 20.0),
(3, "ace", "ace@developintelligence.com", 11.5);
"""

conn = sqlite3.connect('example.db')
cursor = conn.cursor()
cursor.execute(insert_query)
result = cursor.fetchone()
print(result)

conn.commit()
conn.close()

# %%
# Support for "with"

with sqlite3.connect('example.db') as conn:
    query = 'SELECT * FROM users'
    cursor = conn.cursor()
    cursor.execute(query)
    result = cursor.fetchall()
    print(result)

# %%
# Cursors support iteration

with sqlite3.connect('example.db') as conn:
    query = 'SELECT * FROM users'
    cursor = conn.cursor()
    for row in cursor.execute(query):
        print(row[1], row[3])

# %%
# Row objects allow column lookups

with sqlite3.connect('example.db') as conn:
    query = 'SELECT * FROM users'
    conn.row_factory = sqlite3.Row
    cursor = conn.cursor()
    cursor.execute(query)
    for row in cursor:
        print(row['username'], row['pto_days'])
    print(row.keys())

# %%
query = """
INSERT INTO users
VALUES
    (?, ?, ?, ?)"""

# %%
username = input('Enter username: ')
email = input('Enter email: ')
userid = input('Enter ID: ')
days = input('Enter PTO: ')

# %%
with sqlite3.connect('example.db') as conn:
    cursor = conn.cursor()
    cursor.execute(query, (userid, username, email, days))
    for row in cursor.execute('SELECT * from users'):
        print(row)

# %% [markdown]
# ## Bonus Lab:  DBAPI2
#
# Create your own sqlite3 database (HINT:  You can use the filename `:memory:` if you cannot create a file) and execute some SQL queries on it.  Try creating a table and adding a few rows, and then retrieving those rows.

# %% [markdown]
# ## More On Databases
#
# - Python has drivers for PostgreSQL, MySQL, MS-SQL, Oracle, and more!
# - Additional support for No-SQL databases, but they may not follow the DBAPI2 spec
# - If you need to do a LOT of database work, an ORM may help you - look at `sqlalchemy`
# - Database connectivity comes with a lot of gotchas!  Be especially careful when executing within loops.  There's often a better way!

# %% [markdown]
# ## Lab:  Astronomy API Client
# Look for the file **01_calling_apis_with_python.pdf** in your materials for instructions, and build your own standlone script that utilizes the Astronomy API at https://astronomyapi.com
